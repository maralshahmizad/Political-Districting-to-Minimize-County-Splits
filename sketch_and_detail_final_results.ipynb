# %%
import networkx as nx
from gerrychain import Graph
import math
import gurobipy as gp
from gurobipy import GRB

import matplotlib.pyplot as plt
from util import update_attributes, get_k_L_U
from sketch import sketch
from detail import detail
from clusterings import clusterings

filepath1 = 'C:\\districting-data-2020\\'
filepath2 = 'C:\\districting-data-2020-conn\\'

# %%
def number_of_county_splits(districts_geoid):
    county_geoids = { geoid[0:5] for district in districts_geoid for geoid in district }
    county_assignment = { county_geoid : list() for county_geoid in county_geoids }
    for j in range(len(districts_geoid)):
        for geoid in districts_geoid[j]:
            county_geoid = geoid[0:5]
            if j not in county_assignment[county_geoid]:
                county_assignment[county_geoid].append(j)
    return sum( len(county_assignment[cg]) - 1 for cg in county_assignment.keys() )

# %%
import csv

def export_to_baf(geoid_assignment, outfilename):
    
    with open(outfilename, 'w') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        for i in GB.nodes:
            geoid = GB.nodes[i]['GEOID20']
            county = geoid[0:5]
            tract = geoid[0:11]
            block = geoid
            if county in geoid_assignment:
                row = [geoid, geoid_assignment[county]+1]
            elif tract in geoid_assignment:
                row = [geoid, geoid_assignment[tract]+1]
            else:
                row = [geoid, geoid_assignment[block]+1]
            csvwriter.writerow(row) 
    
    return

# %%
from number_of_districts import congressional_districts_2020
states = sorted([ state for state in congressional_districts_2020.keys() ])

results = dict()
instances = list( clusterings.keys() ) 

for (state, district_type) in instances: 

    print("**********************************")
    print("State:",state,"district_type:",district_type)
    print("**********************************")

    # get county graph
    filename = state + '_county.json'
    GC = Graph.from_json( filepath1 + filename )
    update_attributes(GC, state)    

    # get tract graph
    filename = state + '_tract.json'
    GT = Graph.from_json( filepath2 + filename )
    update_attributes(GT, state)    

    # get block graph
    filename = state + '_block.json'
    GB = Graph.from_json( filepath2 + filename )
    update_attributes(GB, state)    

    # get values of k, L, U; check connectivity
    (k, L, U) = get_k_L_U(GC, state, district_type)
    if k <= 1 or not nx.is_connected(GC) or not nx.is_connected(GT) or not nx.is_connected(GB):
        print("Skipping this state because k <= 1 or because graph is disconnected.")
        continue

    clusters = clusterings[state,district_type]['clusters'] 
    sizes = clusterings[state,district_type]['sizes'] 
    districts = list()

    for p in range(len(clusters)):

        cluster = clusters[p]
        size = sizes[p]
        GS = GC.subgraph(cluster)
        
        print("size =",size)
        print("cluster =",cluster)
        print("population = ",[ GS.nodes[i]['TOTPOP'] for i in GS.nodes ] )
        print("L,U =",L,U)

        ################################
        # get a sketch for this cluster
        ################################
        
        (xsoln, ysoln, zsoln) = sketch(GS, L, U, size)
        if xsoln is None:
            print("Sketch indicates that this cluster is infeasible; impossible to get k-1 splits!!!")
            districts = None
            break

        ################################
        # visualize this cluster
        ################################
        
        node_pos = { i : ( GS.nodes[i]['X'], GS.nodes[i]['Y'] ) for i in GS.nodes }
        node_colors = [ list(xsoln[i])[0] for i in GS.nodes ]
        edge_colors = [ list(ysoln[u,v])[0] if len(ysoln[u,v]) > 0 else -1 for u,v in GS.edges ]

        title = state + '_' + district_type
        plt.figure(title)
        my_labels = { i : list(xsoln[i].keys()) for i in GS.nodes }
        nx.draw(GS, pos=node_pos, node_color=node_colors, edge_color=edge_colors, with_labels=True, labels=my_labels, font_color="red")
        plt.show()

        #########################
        # detail this cluster
        #########################
        
        # first, try tract-level
        sketch_support = { GS.nodes[i]['GEOID20'] : list(xsoln[i].keys()) for i in GS.nodes }
        tracts = [ i for i in GT.nodes if GT.nodes[i]['GEOID20'][0:5] in sketch_support.keys() ]
        cluster_districts = detail(GT.subgraph(tracts), L, U, size, sketch_support)
        cluster_districts_geoid = None # just the initial value!

        if cluster_districts is not None:
            cluster_districts_geoid = [ [ GT.nodes[i]['GEOID20'] for i in district ] for district in cluster_districts ]
        else:
            # second, try block-level
            blocks = [ i for i in GB.nodes if GB.nodes[i]['GEOID20'][0:5] in sketch_support.keys() ]
            cluster_districts = detail(GB.subgraph(blocks), L, U, size, sketch_support)
            if cluster_districts is not None:
                cluster_districts_geoid = [ [ GB.nodes[i]['GEOID20'] for i in district ] for district in cluster_districts ]

        # both tries unsuccessful?
        if cluster_districts_geoid is None:
            districts = None
            break
        else:
            districts += cluster_districts_geoid

    # all clusters successful?
    if districts is not None:
        assert k == len(districts)
        splits = number_of_county_splits(districts)
    else:
        districts_geoid = None
        splits = None

    # store results
    results[state,district_type] = dict()
    results[state,district_type]['clusters'] = clusters
    results[state,district_type]['num_clusters'] = len(sizes)
    results[state,district_type]['sizes'] = sizes
    results[state,district_type]['districts'] = districts
    results[state,district_type]['counties'] = GC.number_of_nodes()
    results[state,district_type]['k'] = k
    results[state,district_type]['L'] = L
    results[state,district_type]['U'] = U
    results[state,district_type]['obvious_LB'] = sum( math.ceil( GC.nodes[i]['TOTPOP'] / U ) - 1 for i in GC.nodes )
    results[state,district_type]['splits_LB'] = k - len(sizes)
    results[state,district_type]['splits_UB'] = splits
    
    # export districts to block assignment file
    geoid_assignment = { g : j for j in range(len(districts)) for g in districts[j] }
    outfilename = "min_county_splits_" + state + '_' + district_type + "_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf"
    export_to_baf(geoid_assignment, outfilename)
# Out:
# **********************************
# State: AK district_type: SH
# **********************************
# Starting AK with k = 40 and deviation = 0.1
# Thus, we have L = 17419 and U = 19251
# size = 1
# cluster = [0]
# population =  [18666]
# L,U = 17419 19251
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-27
# size = 6
# cluster = [4, 19]
# population =  [5343, 107081]
# L,U = 17419 19251
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 1126480663.68 	 0.00
# 2 	 1084907339.98 	 0.00
# 3 	 1082536162.26 	 0.00
# 4 	 1081341700.77 	 0.00
# 5 	 1081277732.85 	 0.00
# 6 	 1081277732.85 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [15, 141, 66, 1, 144, 14]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 202 rows, 168 columns and 1074 nonzeros
# Model fingerprint: 0xee6da868
# Variable types: 20 continuous, 148 integer (148 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [6e+03, 5e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 116 rows and 84 columns
# Presolve time: 0.00s
# Presolved: 86 rows, 84 columns, 418 nonzeros
# Variable types: 0 continuous, 84 integer (84 binary)
#
# Root relaxation: objective 1.083228e+09, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.0832e+09    0   10          - 1.0832e+09      -     -    0s
#      0     0 1.0900e+09    0   16          - 1.0900e+09      -     -    0s
#      0     0 1.0905e+09    0   27          - 1.0905e+09      -     -    0s
#      0     0 1.1098e+09    0   30          - 1.1098e+09      -     -    0s
#      0     0 1.1100e+09    0   31          - 1.1100e+09      -     -    0s
#      0     0 1.1119e+09    0   29          - 1.1119e+09      -     -    0s
#      0     0 1.1128e+09    0   32          - 1.1128e+09      -     -    0s
#      0     0 1.1128e+09    0   38          - 1.1128e+09      -     -    0s
#      0     0 1.1248e+09    0   36          - 1.1248e+09      -     -    0s
#      0     0 1.2484e+09    0   35          - 1.2484e+09      -     -    0s
#      0     0 1.2508e+09    0   37          - 1.2508e+09      -     -    0s
#      0     0 1.2508e+09    0   36          - 1.2508e+09      -     -    0s
#      0     0 1.2544e+09    0   36          - 1.2544e+09      -     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 7
#   MIR: 10
#   StrongCG: 5
#   GUB cover: 1
#   RLT: 4
#
# Explored 1 nodes (162 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 40 rows, 168 columns and 504 nonzeros
# Model fingerprint: 0xeac8e97b
# Variable types: 20 continuous, 148 integer (148 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [6e+03, 5e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 4 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 36 rows, 144 columns, 432 nonzeros
# Variable types: 0 continuous, 144 integer (144 binary)
#
# Root relaxation: objective 1.081446e+09, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.0814e+09    0   10          - 1.0814e+09      -     -    0s
#      0     0 1.0900e+09    0   17          - 1.0900e+09      -     -    0s
#      0     0 1.0916e+09    0   12          - 1.0916e+09      -     -    0s
#      0     0 1.0925e+09    0   21          - 1.0925e+09      -     -    0s
#      0     0 1.0941e+09    0   25          - 1.0941e+09      -     -    0s
#      0     0 1.0943e+09    0   24          - 1.0943e+09      -     -    0s
#      0     0 1.0945e+09    0   34          - 1.0945e+09      -     -    0s
#      0     0 1.0963e+09    0   31          - 1.0963e+09      -     -    0s
#      0     0 1.0966e+09    0   34          - 1.0966e+09      -     -    0s
#      0     0 1.0969e+09    0   29          - 1.0969e+09      -     -    0s
#      0     0 1.0969e+09    0   36          - 1.0969e+09      -     -    0s
#      0     0 1.0984e+09    0   26          - 1.0984e+09      -     -    0s
#      0     0 1.0986e+09    0   27          - 1.0986e+09      -     -    0s
#      0     0 1.0986e+09    0   27          - 1.0986e+09      -     -    0s
#      0     0 1.0987e+09    0   32          - 1.0987e+09      -     -    0s
#      0     0 1.0987e+09    0   32          - 1.0987e+09      -     -    0s
#      0     2 1.0988e+09    0   32          - 1.0988e+09      -     -    0s
#  20296 12817 1.1352e+09   39   21          - 1.1127e+09      -  15.1    5s
# *23483 11803              48    1.160180e+09 1.1129e+09  4.08%  15.6    5s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 5
#   Cover: 38
#   MIR: 33
#   StrongCG: 23
#   Flow cover: 5
#   Inf proof: 1
#   Zero half: 3
#   RLT: 3
#   Lazy constraints: 600
#
# Explored 23609 nodes (368674 simplex iterations) in 6.00 seconds (6.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.16018e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.160180034535e+09, best bound 1.112904978121e+09, gap 4.0748%
#
# User-callback calls 49604, time in user-callback 0.29 sec
# size = 1
# cluster = [7, 17]
# population =  [7793, 11031]
# L,U = 17419 19251
# size = 1
# cluster = [6, 8]
# population =  [10046, 8368]
# L,U = 17419 19251
# size = 1
# cluster = [11, 12, 13, 26, 27]
# population =  [662, 2617, 7102, 1619, 6808]
# L,U = 17419 19251
# size = 2
# cluster = [15, 16, 18, 21, 22, 23]
# population =  [2365, 13948, 8458, 5753, 3398, 2127]
# L,U = 17419 19251
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 233738227.93 	 0.00
# 2 	 232336944.38 	 0.00
# 3 	 232336944.38 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [13, 139]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 44 rows, 28 columns and 154 nonzeros
# Model fingerprint: 0xbf0e4ee2
# Variable types: 10 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [4e+04, 4e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 2.641007e+08
# Presolve removed 44 rows and 28 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 2.64101e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.641006938074e+08, best bound 2.641006938074e+08, gap 0.0000%
# size = 16
# cluster = [20]
# population =  [291247]
# L,U = 17419 19251
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 15170637.70 	 0.00
# 2 	 7441856.56 	 0.00
# 3 	 7040998.20 	 0.00
# 4 	 7004074.63 	 0.00
# 5 	 7001791.54 	 0.00
# 6 	 7001740.24 	 0.00
# 7 	 7001702.14 	 0.00
# 8 	 7001702.14 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [61, 156, 158, 45, 41, 42, 169, 34, 50, 33, 62, 64, 166, 40, 57, 55]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1053 rows, 976 columns and 6464 nonzeros
# Model fingerprint: 0x87663177
# Variable types: 0 continuous, 976 integer (976 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [6e+01, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 782 rows and 706 columns
# Presolve time: 0.03s
# Presolved: 271 rows, 270 columns, 1369 nonzeros
# Variable types: 0 continuous, 270 integer (270 binary)
#
# Root relaxation: objective 8.773752e+06, 70 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8773751.90    0   21          - 8773751.90      -     -    0s
#      0     0 9449168.85    0   47          - 9449168.85      -     -    0s
#      0     0 9547448.33    0   47          - 9547448.33      -     -    0s
#      0     0 9565571.76    0   47          - 9565571.76      -     -    0s
#      0     0 9565891.52    0   42          - 9565891.52      -     -    0s
# H    0     0                    1.283571e+07 9619906.72  25.1%     -    0s
#      0     0 9619906.72    0   47 1.2836e+07 9619906.72  25.1%     -    0s
#      0     0 9622721.43    0   48 1.2836e+07 9622721.43  25.0%     -    0s
#      0     0 9622729.92    0   51 1.2836e+07 9622729.92  25.0%     -    0s
# H    0     0                    1.218386e+07 9622729.92  21.0%     -    0s
# H    0     0                    9941846.4048 9622729.92  3.21%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 2
#   Cover: 12
#   Clique: 4
#   MIR: 21
#   StrongCG: 9
#   GUB cover: 8
#   RLT: 6
#
# Explored 1 nodes (203 simplex iterations) in 0.10 seconds (0.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 9.94185e+06 1.21839e+07 1.28357e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.941846404839e+06, best bound 9.622729921354e+06, gap 3.2098%
# size = 2
# cluster = [14, 24, 29]
# population =  [32255, 2080, 1240]
# L,U = 17419 19251
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 45305774.58 	 0.00
# 2 	 38517772.15 	 0.00
# 3 	 38517772.15 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [119, 121]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 26 rows, 16 columns and 92 nonzeros
# Model fingerprint: 0xe200a1e1
# Variable types: 2 continuous, 14 integer (14 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [3e+05, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 5.098407e+07
# Presolve removed 26 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 5.09841e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.098407262632e+07, best bound 5.098407262632e+07, gap 0.0000%
# size = 5
# cluster = [1, 2, 3, 5, 9, 10, 25]
# population =  [1476, 844, 4857, 3420, 5232, 13101, 58799]
# L,U = 17419 19251
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 4875885334.50 	 0.00
# 2 	 4847500132.39 	 0.00
# 3 	 4847397499.41 	 0.00
# 4 	 4847396016.06 	 0.00
# 5 	 4847396016.06 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [96, 7, 99, 149, 18]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 161 rows, 130 columns and 775 nonzeros
# Model fingerprint: 0x991bde31
# Variable types: 48 continuous, 82 integer (82 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [4e+05, 7e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 109 rows and 85 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 36 rows, 130 columns and 390 nonzeros
# Model fingerprint: 0xa360a35d
# Variable types: 48 continuous, 82 integer (82 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [4e+05, 7e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 14 rows and 75 columns
# Presolve time: 0.00s
# Presolved: 22 rows, 55 columns, 162 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 5.250409e+09, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.2504e+09    0    4          - 5.2504e+09      -     -    0s
#      0     0 5.2621e+09    0   11          - 5.2621e+09      -     -    0s
#      0     0 5.2652e+09    0    4          - 5.2652e+09      -     -    0s
#      0     0 5.2654e+09    0    2          - 5.2654e+09      -     -    0s
#      0     0 5.2661e+09    0   14          - 5.2661e+09      -     -    0s
#      0     0 5.2668e+09    0   14          - 5.2668e+09      -     -    0s
#      0     0 5.2688e+09    0   16          - 5.2688e+09      -     -    0s
#      0     0 5.2690e+09    0   17          - 5.2690e+09      -     -    0s
#      0     0 5.2691e+09    0   19          - 5.2691e+09      -     -    0s
#      0     0 5.2691e+09    0   20          - 5.2691e+09      -     -    0s
#      0     0 5.2691e+09    0   20          - 5.2691e+09      -     -    0s
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Cutting planes:
#   Cover: 6
#   Clique: 2
#   MIR: 4
#   StrongCG: 3
#   Lazy constraints: 12
#
# Explored 1 nodes (76 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 269, time in user-callback 0.01 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.04
# 1 	 4095898994.36 	 0.02
# 2 	 4048740882.50 	 0.01
# 3 	 4047307167.15 	 0.01
# 4 	 4047243953.73 	 0.01
# 5 	 4047239279.70 	 0.01
# 6 	 4047239275.35 	 0.01
# 7 	 4047239275.35 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [4819, 14479, 20479, 24888, 20912]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 35909 rows, 29920 columns and 147830 nonzeros
# Model fingerprint: 0x45a0a27e
# Variable types: 13136 continuous, 16784 integer (16784 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 23892 rows and 19937 columns
# Presolve time: 1.11s
# Presolved: 12017 rows, 9983 columns, 51888 nonzeros
# Variable types: 0 continuous, 9983 integer (9983 binary)
#
# Root relaxation: objective 4.047553e+09, 4756 iterations, 0.09 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.0476e+09    0  252          - 4.0476e+09      -     -    1s
#      0     0 4.0490e+09    0  716          - 4.0490e+09      -     -    2s
#      0     0 4.0490e+09    0  783          - 4.0490e+09      -     -    2s
#      0     0 4.0490e+09    0  788          - 4.0490e+09      -     -    2s
#      0     0 4.0490e+09    0  790          - 4.0490e+09      -     -    2s
#      0     0 4.0498e+09    0  778          - 4.0498e+09      -     -    2s
#      0     0 4.0499e+09    0  758          - 4.0499e+09      -     -    2s
#      0     0 4.0499e+09    0  758          - 4.0499e+09      -     -    2s
#      0     0 4.0518e+09    0  818          - 4.0518e+09      -     -    3s
#      0     0 4.0518e+09    0  347          - 4.0518e+09      -     -    3s
#      0     0 4.0518e+09    0  356          - 4.0518e+09      -     -    3s
#      0     0 4.0542e+09    0  844          - 4.0542e+09      -     -    4s
#      0     0 4.0542e+09    0  398          - 4.0542e+09      -     -    4s
#      0     0 4.0542e+09    0  408          - 4.0542e+09      -     -    4s
#      0     0 4.0542e+09    0  823          - 4.0542e+09      -     -    4s
#      0     0 4.0542e+09    0  827          - 4.0542e+09      -     -    4s
#      0     0 4.0542e+09    0  811          - 4.0542e+09      -     -    5s
#      0     0 4.0542e+09    0  720          - 4.0542e+09      -     -    5s
#      0     2 4.0542e+09    0  720          - 4.0542e+09      -     -    6s
# *  528   333             119    4.067163e+09 4.0545e+09  0.31%  47.2    8s
#
# Cutting planes:
#   Gomory: 48
#   Implied bound: 7
#   Clique: 2078
#   MIR: 25
#   GUB cover: 1
#   Zero half: 22
#   RLT: 22
#
# Explored 531 nodes (39213 simplex iterations) in 8.07 seconds (4.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 4.06716e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.067163010030e+09, best bound 4.054527403928e+09, gap 0.3107%
# size = 5
# cluster = [28]
# population =  [95655]
# L,U = 17419 19251
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 55039232.90 	 0.00
# 2 	 36790364.32 	 0.00
# 3 	 35044974.78 	 0.00
# 4 	 35044974.78 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [130, 124, 90, 79, 92]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 137 rows, 110 columns and 725 nonzeros
# Model fingerprint: 0xc7c45be8
# Variable types: 0 continuous, 110 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [7e+02, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 60 rows and 39 columns
# Presolve time: 0.00s
# Presolved: 77 rows, 71 columns, 363 nonzeros
# Variable types: 0 continuous, 71 integer (71 binary)
#
# Root relaxation: objective 3.518329e+07, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.5183e+07    0    7          - 3.5183e+07      -     -    0s
#      0     0 3.8270e+07    0   28          - 3.8270e+07      -     -    0s
#      0     0 3.9538e+07    0   29          - 3.9538e+07      -     -    0s
#      0     0 3.9600e+07    0   29          - 3.9600e+07      -     -    0s
#      0     0 3.9715e+07    0   30          - 3.9715e+07      -     -    0s
#      0     0 3.9731e+07    0   30          - 3.9731e+07      -     -    0s
#      0     0 4.7587e+07    0   37          - 4.7587e+07      -     -    0s
#      0     0 5.0132e+07    0   37          - 5.0132e+07      -     -    0s
#      0     0 5.0132e+07    0   35          - 5.0132e+07      -     -    0s
#      0     0 5.1709e+07    0   36          - 5.1709e+07      -     -    0s
#      0     0 5.1709e+07    0   36          - 5.1709e+07      -     -    0s
#      0     0 1.000e+100    0   29          - infeasible      -     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 3
#   Clique: 3
#   MIR: 6
#   StrongCG: 5
#   RLT: 3
#
# Explored 1 nodes (203 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 32 rows, 110 columns and 330 nonzeros
# Model fingerprint: 0x58b5c0b7
# Variable types: 0 continuous, 110 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [7e+02, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve time: 0.00s
# Presolved: 32 rows, 110 columns, 330 nonzeros
# Variable types: 0 continuous, 110 integer (110 binary)
#
# Root relaxation: objective 3.504497e+07, 39 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.5045e+07    0    8          - 3.5045e+07      -     -    0s
#      0     0 3.5792e+07    0   11          - 3.5792e+07      -     -    0s
#      0     0 3.5963e+07    0    8          - 3.5963e+07      -     -    0s
#      0     0 3.6270e+07    0   18          - 3.6270e+07      -     -    0s
#      0     0 3.6315e+07    0   21          - 3.6315e+07      -     -    0s
#      0     0 3.6315e+07    0   21          - 3.6315e+07      -     -    0s
#      0     0 3.6421e+07    0   23          - 3.6421e+07      -     -    0s
#      0     0 3.6460e+07    0   27          - 3.6460e+07      -     -    0s
#      0     0 3.6485e+07    0   28          - 3.6485e+07      -     -    0s
#      0     0 3.6486e+07    0   26          - 3.6486e+07      -     -    0s
#      0     0 3.6632e+07    0   25          - 3.6632e+07      -     -    0s
#      0     0 3.6831e+07    0   18          - 3.6831e+07      -     -    0s
#      0     0 3.6859e+07    0   29          - 3.6859e+07      -     -    0s
#      0     0 3.6881e+07    0   36          - 3.6881e+07      -     -    0s
#      0     0 3.6982e+07    0   32          - 3.6982e+07      -     -    0s
#      0     0 3.6998e+07    0   38          - 3.6998e+07      -     -    0s
#      0     0 3.7000e+07    0   40          - 3.7000e+07      -     -    0s
#      0     0 3.7060e+07    0   37          - 3.7060e+07      -     -    0s
#      0     0 3.7082e+07    0   33          - 3.7082e+07      -     -    0s
#      0     0 3.7086e+07    0   34          - 3.7086e+07      -     -    0s
#      0     0 3.7226e+07    0   38          - 3.7226e+07      -     -    0s
#      0     0 3.7274e+07    0   41          - 3.7274e+07      -     -    0s
#      0     0 3.7280e+07    0   43          - 3.7280e+07      -     -    0s
#      0     0 3.7287e+07    0   41          - 3.7287e+07      -     -    0s
#      0     0 3.7374e+07    0   41          - 3.7374e+07      -     -    0s
#      0     0 3.7386e+07    0   37          - 3.7386e+07      -     -    0s
#      0     0 3.7387e+07    0   39          - 3.7387e+07      -     -    0s
#      0     0 3.7507e+07    0   38          - 3.7507e+07      -     -    0s
#      0     0 3.7522e+07    0   38          - 3.7522e+07      -     -    0s
#      0     0 3.7529e+07    0   41          - 3.7529e+07      -     -    0s
#      0     0 3.7535e+07    0   40          - 3.7535e+07      -     -    0s
#      0     0 3.7535e+07    0   40          - 3.7535e+07      -     -    0s
#      0     2 3.7746e+07    0   40          - 3.7746e+07      -     -    0s
#  51312 28511 7.4014e+07   40   17          - 4.1522e+07      -  11.4    5s
#  90389 46916 1.5117e+08   41   17          - 4.2994e+07      -  12.8   10s
#  124862 61260 8.0996e+07   42   10          - 4.4090e+07      -  13.5   15s
#  161119 75432 5.7816e+07   29   44          - 4.5127e+07      -  13.9   20s
#  197522 89281 infeasible   34               - 4.6147e+07      -  14.2   25s
#  229167 100929 7.5902e+07   35   33          - 4.6963e+07      -  14.5   30s
#  259820 111761 6.2410e+07   32   21          - 4.7711e+07      -  14.7   35s
#  291247 122724 7.7446e+07   33   26          - 4.8529e+07      -  15.0   40s
#  317885 131099 7.8411e+07   30   33          - 4.9330e+07      -  15.2   45s
#  342279 138608 6.5368e+07   43   22          - 5.0009e+07      -  15.3   50s
#  366727 146080 infeasible   37               - 5.0641e+07      -  15.5   55s
#  390002 152583 8.6629e+07   39   31          - 5.1325e+07      -  15.6   60s
#  411659 158777 5.6212e+07   30   41          - 5.1912e+07      -  15.8   65s
#  433429 164875 infeasible   42               - 5.2488e+07      -  15.9   70s
#  454841 171149 infeasible   43               - 5.3044e+07      -  16.1   75s
#  475555 177121 7.2356e+07   38   25          - 5.3518e+07      -  16.2   80s
#  496144 182909 infeasible   36               - 5.4040e+07      -  16.3   85s
#  515569 188238 1.3675e+08   36   21          - 5.4497e+07      -  16.4   90s
#  535437 193970 1.7387e+08   46   15          - 5.4943e+07      -  16.5   95s
#  552511 198814 7.3097e+07   40   22          - 5.5372e+07      -  16.6  100s
#  571542 204190 1.4404e+08   48   15          - 5.5824e+07      -  16.7  105s
#  589724 209140 infeasible   36               - 5.6202e+07      -  16.8  110s
#  606343 213350 1.1101e+08   42   25          - 5.6588e+07      -  16.8  115s
#  624368 218316 infeasible   42               - 5.6978e+07      -  16.9  120s
#  641247 222630 7.8359e+07   42   27          - 5.7311e+07      -  17.0  125s
#  659907 228002 1.7972e+08   51   22          - 5.7676e+07      -  17.1  130s
#  678999 233331 infeasible   40               - 5.8044e+07      -  17.1  135s
#  695389 237840 1.0453e+08   37   25          - 5.8356e+07      -  17.2  140s
#  711177 242231 1.3881e+08   38   20          - 5.8644e+07      -  17.3  145s
#  726936 246288 infeasible   44               - 5.8948e+07      -  17.3  150s
#  743120 250220 infeasible   37               - 5.9253e+07      -  17.4  155s
#  758637 254516 6.7147e+07   35   31          - 5.9522e+07      -  17.4  160s
#  773566 258363 1.1068e+08   36   29          - 5.9772e+07      -  17.5  165s
#  787985 262225 1.1303e+08   43   34          - 6.0012e+07      -  17.6  170s
#  802106 265843 6.6536e+07   34   39          - 6.0243e+07      -  17.6  175s
#  816472 269351 8.6007e+07   45   35          - 6.0492e+07      -  17.7  180s
#  830633 273075 infeasible   43               - 6.0735e+07      -  17.7  185s
#  844754 276829 1.1544e+08   45   16          - 6.0962e+07      -  17.8  190s
#  860042 280706 infeasible   38               - 6.1210e+07      -  17.8  195s
#  874050 284172 infeasible   51               - 6.1428e+07      -  17.9  200s
#  887816 287440 infeasible   44               - 6.1644e+07      -  17.9  205s
#  901909 290699 infeasible   38               - 6.1855e+07      -  17.9  210s
#  915202 294164 1.3787e+08   35   17          - 6.2060e+07      -  18.0  215s
#  928179 297308 1.0537e+08   39   36          - 6.2252e+07      -  18.0  220s
#  940445 300297 1.5696e+08   29   27          - 6.2432e+07      -  18.1  225s
#  952793 303251 1.0230e+08   45   35          - 6.2613e+07      -  18.1  230s
#  966247 306539 1.1919e+08   41   35          - 6.2818e+07      -  18.2  235s
#  978744 309713 1.0754e+08   35   30          - 6.3012e+07      -  18.2  240s
#  990925 312689 infeasible   46               - 6.3181e+07      -  18.2  245s
#  1003760 315979 1.2295e+08   44   35          - 6.3377e+07      -  18.3  250s
#  1018524 319577 infeasible   33               - 6.3584e+07      -  18.3  255s
#  1032468 323022 8.5250e+07   31   33          - 6.3798e+07      -  18.4  260s
#  1046167 326436 1.4660e+08   42    8          - 6.3997e+07      -  18.4  265s
#  1061063 330045 9.7562e+07   39   39          - 6.4200e+07      -  18.5  270s
#  1074457 333425 8.4517e+07   41   30          - 6.4378e+07      -  18.5  275s
#  1088998 336203 infeasible   39               - 6.4479e+07      -  18.5  280s
#  1102569 339397 infeasible   45               - 6.4658e+07      -  18.6  285s
#  1113969 341996 infeasible   40               - 6.4803e+07      -  18.6  290s
#  1125468 344659 9.4065e+07   45   32          - 6.4969e+07      -  18.6  295s
#  1136634 347269 8.4016e+07   43   36          - 6.5112e+07      -  18.7  300s
#  1147555 349805 infeasible   42               - 6.5261e+07      -  18.7  305s
#  1159642 352448 1.2081e+08   54   16          - 6.5432e+07      -  18.7  310s
#  1170784 354650 9.5052e+07   32   33          - 6.5587e+07      -  18.7  315s
#  1182315 356344 9.4574e+07   37   29          - 6.5692e+07      -  18.8  320s
#  1192932 358618 infeasible   41               - 6.5830e+07      -  18.8  325s
#  1203589 360971 8.1611e+07   46   41          - 6.5973e+07      -  18.8  330s
#  1214775 363201 infeasible   36               - 6.6117e+07      -  18.8  335s
#  1225270 365520 1.5599e+08   48   34          - 6.6253e+07      -  18.9  340s
#  1236616 367962 1.1759e+08   39   34          - 6.6410e+07      -  18.9  345s
#  1247636 370190 infeasible   40               - 6.6544e+07      -  18.9  350s
#  1259564 372482 9.2514e+07   40   29          - 6.6706e+07      -  19.0  355s
#  1271499 374779 1.1071e+08   39   27          - 6.6856e+07      -  19.0  360s
#  1283626 377291 9.6954e+07   40   40          - 6.7022e+07      -  19.0  365s
#  1296183 379899 8.6108e+07   38   42          - 6.7181e+07      -  19.0  370s
#  1307649 382469 infeasible   37               - 6.7321e+07      -  19.1  375s
#  1319299 384871 8.2823e+07   38   31          - 6.7468e+07      -  19.1  380s
#  1332179 387542 infeasible   43               - 6.7626e+07      -  19.1  385s
#  1344305 389927 infeasible   35               - 6.7767e+07      -  19.1  390s
#  1356594 392368 1.1683e+08   34   26          - 6.7932e+07      -  19.2  395s
#  1369234 395104 8.8922e+07   36   31          - 6.8094e+07      -  19.2  400s
#  1381162 397418 1.3625e+08   48   33          - 6.8243e+07      -  19.2  405s
#  1390965 399156 9.4858e+07   43   37          - 6.8369e+07      -  19.2  410s
#  1401251 401260 1.7595e+08   38   29          - 6.8501e+07      -  19.3  415s
#  1411458 403392 1.0013e+08   41   32          - 6.8630e+07      -  19.3  420s
#  1422110 405380 1.1150e+08   39   32          - 6.8762e+07      -  19.3  425s
#  1431995 407382 1.1866e+08   42   27          - 6.8878e+07      -  19.3  430s
#  1441575 409278 infeasible   32               - 6.8999e+07      -  19.3  435s
#  1451924 411546 9.2980e+07   35   29          - 6.9118e+07      -  19.4  440s
#  1461557 413283 infeasible   47               - 6.9232e+07      -  19.4  445s
#  1471012 415128 infeasible   35               - 6.9351e+07      -  19.4  450s
#  1481478 417065 1.1630e+08   36   38          - 6.9486e+07      -  19.4  455s
#  1491594 418963 1.0012e+08   40   23          - 6.9614e+07      -  19.4  460s
#  1501058 420885 1.2084e+08   49   35          - 6.9730e+07      -  19.4  465s
#  1512094 422935 8.7966e+07   44   33          - 6.9882e+07      -  19.5  470s
#  1523960 425032 infeasible   43               - 7.0028e+07      -  19.5  475s
#  1535025 427317 infeasible   45               - 7.0147e+07      -  19.5  480s
#  1547152 429622 9.5710e+07   41   30          - 7.0296e+07      -  19.5  485s
#  1558070 431630 infeasible   35               - 7.0426e+07      -  19.5  490s
#  1569771 433676 8.0960e+07   33   39          - 7.0571e+07      -  19.6  495s
#  1579788 435549 1.0619e+08   43   37          - 7.0692e+07      -  19.6  500s
#  1591430 437710 infeasible   35               - 7.0834e+07      -  19.6  505s
#  1603240 439843 infeasible   45               - 7.0973e+07      -  19.6  510s
#  1613893 441853 8.8990e+07   37   39          - 7.1091e+07      -  19.6  515s
#  1625156 443993 infeasible   53               - 7.1223e+07      -  19.6  520s
#  1635791 445780 infeasible   47               - 7.1352e+07      -  19.7  525s
#  1644604 447310 1.2694e+08   46   35          - 7.1470e+07      -  19.7  530s
#  1654053 449265 1.2691e+08   42   23          - 7.1590e+07      -  19.7  535s
#  1664087 451235 infeasible   35               - 7.1714e+07      -  19.7  540s
#  1672661 452982 1.0358e+08   34   37          - 7.1813e+07      -  19.7  545s
#  1682462 454713 9.3860e+07   44   47          - 7.1929e+07      -  19.7  550s
#  1691939 456404 infeasible   37               - 7.2043e+07      -  19.7  555s
#  1701634 458079 9.8149e+07   42   37          - 7.2167e+07      -  19.7  560s
#  1710886 459815 1.3987e+08   43   36          - 7.2281e+07      -  19.7  565s
#  1720531 461412 9.0526e+07   39   35          - 7.2400e+07      -  19.8  570s
#  1730038 463167 infeasible   34               - 7.2520e+07      -  19.8  575s
#  1739092 464758 infeasible   48               - 7.2622e+07      -  19.8  580s
#  1749489 466369 9.1096e+07   36   39          - 7.2742e+07      -  19.8  585s
#  1758463 467908 7.6007e+07   37   41          - 7.2857e+07      -  19.8  590s
#  1768701 469579 infeasible   38               - 7.2986e+07      -  19.8  595s
#  1778342 471236 8.3599e+07   29   34          - 7.3103e+07      -  19.8  600s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 1089
#   MIR: 51
#   StrongCG: 33
#   Flow cover: 7
#   Inf proof: 37
#   Zero half: 4
#   RLT: 1
#   Lazy constraints: 520
#
# Explored 1778737 nodes (35249462 simplex iterations) in 600.02 seconds (801.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 7.310556044897e+07, gap -
#
# User-callback calls 3713704, time in user-callback 10.41 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.04
# 1 	 17128755.21 	 0.02
# 2 	 7453400.70 	 0.01
# 3 	 5603588.74 	 0.01
# 4 	 5433116.31 	 0.00
# 5 	 5431151.95 	 0.00
# 6 	 5426840.57 	 0.01
# 7 	 5424101.74 	 0.00
# 8 	 5423135.81 	 0.00
# 9 	 5422573.83 	 0.00
# 10 	 5421842.45 	 0.00
# 11 	 5420826.23 	 0.00
# 12 	 5420509.22 	 0.00
# 13 	 5420079.77 	 0.00
# 14 	 5419781.27 	 0.00
# 15 	 5419717.76 	 0.00
# 16 	 5419614.17 	 0.00
# 17 	 5419454.33 	 0.01
# 18 	 5419399.29 	 0.01
# 19 	 5419394.07 	 0.00
# 20 	 5419393.11 	 0.00
# 21 	 5419392.99 	 0.01
# 22 	 5419392.99 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [23836, 20585, 8219, 27069, 4454]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17207 rows, 14335 columns and 82015 nonzeros
# Model fingerprint: 0x777165bb
# Variable types: 0 continuous, 14335 integer (14335 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [7e-02, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 1589 rows and 1309 columns
# Presolve time: 0.85s
# Presolved: 15618 rows, 13026 columns, 71310 nonzeros
# Variable types: 0 continuous, 13026 integer (13026 binary)
#
# Root relaxation: objective 5.423706e+06, 5985 iterations, 0.09 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5423705.65    0  106          - 5423705.65      -     -    1s
# H    0     0                    5621681.4105 5423705.65  3.52%     -    1s
#
# Explored 1 nodes (10273 simplex iterations) in 1.41 seconds (0.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5.62168e+06
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.621681410455e+06, best bound 5.423705652511e+06, gap 3.5216%
# **********************************
# State: AL district_type: SH
# **********************************
# Starting AL with k = 105 and deviation = 0.1
# Thus, we have L = 45458 and U = 50242
# size = 5
# cluster = [0, 32, 54]
# population =  [223024, 14236, 10387]
# L,U = 45458 50242
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 84369474.53 	 0.00
# 2 	 63992185.76 	 0.00
# 3 	 63278992.43 	 0.00
# 4 	 62839674.54 	 0.00
# 5 	 62645079.56 	 0.00
# 6 	 62564440.70 	 0.00
# 7 	 62564440.70 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [1223, 13, 930, 1170, 1158]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 377 rows, 310 columns and 1965 nonzeros
# Model fingerprint: 0x56842ce3
# Variable types: 28 continuous, 282 integer (282 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [1e+02, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 105 rows and 76 columns
# Presolve time: 0.01s
# Presolved: 272 rows, 234 columns, 1377 nonzeros
# Variable types: 0 continuous, 234 integer (234 binary)
#
# Root relaxation: objective 6.256444e+07, 75 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.2564e+07    0    8          - 6.2564e+07      -     -    0s
# H    0     0                    6.842556e+07 6.2564e+07  8.57%     -    0s
#
# Explored 1 nodes (75 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6.84256e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.842555901072e+07, best bound 6.256444069611e+07, gap 8.5657%
# size = 1
# cluster = [1, 53]
# population =  [38462, 10311]
# L,U = 45458 50242
# size = 1
# cluster = [2, 17, 43]
# population =  [13972, 19123, 16321]
# L,U = 45458 50242
# size = 2
# cluster = [3]
# population =  [93564]
# L,U = 45458 50242
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 15766610.32 	 0.00
# 2 	 11381849.36 	 0.00
# 3 	 11381685.79 	 0.00
# 4 	 11381685.79 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [616, 618]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 80 rows, 52 columns and 322 nonzeros
# Model fingerprint: 0x9592f19a
# Variable types: 0 continuous, 52 integer (52 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [9e+03, 8e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 48 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 22 columns, 125 nonzeros
# Variable types: 0 continuous, 22 integer (22 binary)
# Found heuristic solution: objective 1.277534e+07
# Found heuristic solution: objective 1.142492e+07
#
# Root relaxation: objective 1.138169e+07, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1382e+07    0    1 1.1425e+07 1.1382e+07  0.38%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.14249e+07 1.27753e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.142491745053e+07, best bound 1.138168579342e+07, gap 0.3784%
# size = 4
# cluster = [6, 7, 10, 31]
# population =  [107202, 17146, 26659, 49326]
# L,U = 45458 50242
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 48715999.14 	 0.00
# 2 	 45054333.05 	 0.00
# 3 	 45012029.97 	 0.00
# 4 	 45006940.99 	 0.00
# 5 	 45006940.99 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [904, 613, 1414, 1412]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 264 rows, 208 columns and 1344 nonzeros
# Model fingerprint: 0x999a9dd6
# Variable types: 90 continuous, 118 integer (118 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+03, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 161 rows and 130 columns
# Presolve time: 0.00s
# Presolved: 103 rows, 78 columns, 490 nonzeros
# Variable types: 0 continuous, 78 integer (78 binary)
#
# Root relaxation: objective 4.500694e+07, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.5007e+07    0    5          - 4.5007e+07      -     -    0s
#      0     0 4.9105e+07    0   18          - 4.9105e+07      -     -    0s
#      0     0 5.2410e+07    0   24          - 5.2410e+07      -     -    0s
#      0     0 5.6089e+07    0   30          - 5.6089e+07      -     -    0s
#      0     0 5.6917e+07    0   29          - 5.6917e+07      -     -    0s
#      0     0 6.0555e+07    0   26          - 6.0555e+07      -     -    0s
#      0     0 6.0555e+07    0   27          - 6.0555e+07      -     -    0s
#      0     0 6.0606e+07    0   27          - 6.0606e+07      -     -    0s
#      0     0 6.0606e+07    0   26          - 6.0606e+07      -     -    0s
#      0     0 6.0606e+07    0   29          - 6.0606e+07      -     -    0s
#      0     0 6.0606e+07    0   29          - 6.0606e+07      -     -    0s
#      0     0 6.1188e+07    0   12          - 6.1188e+07      -     -    0s
#      0     0 6.1188e+07    0   24          - 6.1188e+07      -     -    0s
#      0     0 6.1418e+07    0   25          - 6.1418e+07      -     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 4
#   StrongCG: 7
#   GUB cover: 2
#
# Explored 1 nodes (172 simplex iterations) in 0.08 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 60 rows, 208 columns and 624 nonzeros
# Model fingerprint: 0xec826bc6
# Variable types: 90 continuous, 118 integer (118 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+03, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 27 rows and 118 columns
# Presolve time: 0.00s
# Presolved: 33 rows, 90 columns, 285 nonzeros
# Variable types: 0 continuous, 90 integer (90 binary)
#
# Root relaxation: objective 4.500694e+07, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.5007e+07    0    5          - 4.5007e+07      -     -    0s
#      0     0 4.7768e+07    0   12          - 4.7768e+07      -     -    0s
#      0     0 4.9865e+07    0   12          - 4.9865e+07      -     -    0s
#      0     0 5.0672e+07    0   20          - 5.0672e+07      -     -    0s
#      0     0 5.0693e+07    0   20          - 5.0693e+07      -     -    0s
#      0     0 5.0718e+07    0   22          - 5.0718e+07      -     -    0s
#      0     0 5.0776e+07    0   24          - 5.0776e+07      -     -    0s
#      0     0 5.0782e+07    0   22          - 5.0782e+07      -     -    0s
#      0     0 5.0822e+07    0   22          - 5.0822e+07      -     -    0s
#      0     0 5.0826e+07    0   23          - 5.0826e+07      -     -    0s
#      0     0 5.0846e+07    0   25          - 5.0846e+07      -     -    0s
#      0     0 5.0848e+07    0   25          - 5.0848e+07      -     -    0s
#      0     0 5.0860e+07    0   23          - 5.0860e+07      -     -    0s
#      0     0 5.0878e+07    0   23          - 5.0878e+07      -     -    0s
#      0     0 5.0927e+07    0   23          - 5.0927e+07      -     -    0s
#      0     0 5.0929e+07    0   25          - 5.0929e+07      -     -    0s
#      0     0 5.1335e+07    0   20          - 5.1335e+07      -     -    0s
#      0     0 5.1344e+07    0   22          - 5.1344e+07      -     -    0s
#      0     0 5.1345e+07    0   21          - 5.1345e+07      -     -    0s
#      0     0 5.1507e+07    0   18          - 5.1507e+07      -     -    0s
#      0     0 5.1582e+07    0   23          - 5.1582e+07      -     -    0s
#      0     0 5.1584e+07    0   24          - 5.1584e+07      -     -    0s
#      0     0 5.1645e+07    0   29          - 5.1645e+07      -     -    0s
#      0     0 5.1646e+07    0   32          - 5.1646e+07      -     -    0s
#      0     0 5.1706e+07    0   26          - 5.1706e+07      -     -    0s
#      0     0 5.1716e+07    0   28          - 5.1716e+07      -     -    0s
#      0     0 5.1735e+07    0   29          - 5.1735e+07      -     -    0s
#      0     0 5.1735e+07    0   29          - 5.1735e+07      -     -    0s
#      0     2 5.2045e+07    0   29          - 5.2045e+07      -     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 4
#   MIR: 25
#   StrongCG: 7
#   Flow cover: 10
#   Inf proof: 4
#   Zero half: 1
#   Lazy constraints: 87
#
# Explored 6971 nodes (27139 simplex iterations) in 0.61 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 14458, time in user-callback 0.16 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.05
# 1 	 50361384.80 	 0.02
# 2 	 45493576.27 	 0.02
# 3 	 45484711.70 	 0.01
# 4 	 45483872.80 	 0.01
# 5 	 45483800.78 	 0.01
# 6 	 45483772.69 	 0.01
# 7 	 45483763.19 	 0.01
# 8 	 45483761.63 	 0.01
# 9 	 45483761.63 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [62771, 72953, 89963, 155446]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 43269 rows, 34612 columns and 205216 nonzeros
# Model fingerprint: 0x8e3fe056
# Variable types: 16764 continuous, 17848 integer (17848 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [3e-01, 2e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 26968 rows and 23009 columns
# Presolve time: 1.05s
# Presolved: 16301 rows, 11603 columns, 65415 nonzeros
# Variable types: 0 continuous, 11603 integer (11600 binary)
#
# Root relaxation: objective 4.548390e+07, 4776 iterations, 0.05 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.5484e+07    0    8          - 4.5484e+07      -     -    1s
# H    0     0                    4.549605e+07 4.5484e+07  0.03%     -    1s
#
# Explored 1 nodes (6209 simplex iterations) in 1.45 seconds (0.72 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 4.54961e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.549605109826e+07, best bound 4.548389967515e+07, gap 0.0267%
# size = 2
# cluster = [8, 24, 44]
# population =  [41311, 21967, 34772]
# L,U = 45458 50242
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 65589143.50 	 0.00
# 2 	 64384632.88 	 0.00
# 3 	 64268054.60 	 0.00
# 4 	 64268054.60 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [1282, 546]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 83 rows, 54 columns and 324 nonzeros
# Model fingerprint: 0xd9e32007
# Variable types: 21 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [6e+04, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+04]
# Presolve removed 81 rows and 54 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 31 rows, 54 columns and 162 nonzeros
# Model fingerprint: 0xaafd2469
# Variable types: 21 continuous, 33 integer (33 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [6e+04, 2e+07]
#   Bounds range     [1e+00, 1e+00]
# ...
# Optimize a model with 719 rows, 478 columns and 3144 nonzeros
# Model fingerprint: 0x43511c12
# Variable types: 65 continuous, 413 integer (413 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 436 rows and 324 columns
# Presolve time: 0.01s
# Presolved: 283 rows, 154 columns, 1186 nonzeros
# Variable types: 0 continuous, 154 integer (154 binary)
# Found heuristic solution: objective 1.381438e+09
# Found heuristic solution: objective 1.254273e+09
#
# Root relaxation: objective 1.240575e+09, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2406e+09    0    1 1.2543e+09 1.2406e+09  1.09%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.25427e+09 1.38144e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.254272570652e+09, best bound 1.240574525430e+09, gap 1.0921%
# size = 5
# cluster = [13, 40]
# population =  [873965, 1682353]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.01
# 1 	 415542684.82 	 0.00
# 2 	 142393183.41 	 0.00
# 3 	 140848597.39 	 0.00
# 4 	 140740241.62 	 0.00
# 5 	 140659853.06 	 0.00
# 6 	 140608277.34 	 0.00
# 7 	 140382218.41 	 0.00
# 8 	 140198420.82 	 0.00
# 9 	 140045798.95 	 0.00
# 10 	 140013488.17 	 0.00
# 11 	 139998597.04 	 0.00
# 12 	 139993454.61 	 0.00
# 13 	 139991202.66 	 0.00
# 14 	 139991202.66 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [7269, 5645, 513, 8974, 8204]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 3743 rows, 3115 columns and 20745 nonzeros
# Model fingerprint: 0x17300378
# Variable types: 1111 continuous, 2004 integer (2004 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [8e+02, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 1600 rows and 1485 columns
# Presolve time: 0.10s
# Presolved: 2143 rows, 1630 columns, 10049 nonzeros
# Variable types: 0 continuous, 1630 integer (1627 binary)
#
# Root relaxation: objective 1.402020e+08, 407 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.4020e+08    0   10          - 1.4020e+08      -     -    0s
# H    0     0                    1.410690e+08 1.4020e+08  0.61%     -    0s
#
# Explored 1 nodes (407 simplex iterations) in 0.15 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.41069e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.410689733056e+08, best bound 1.402020236384e+08, gap 0.6146%
# size = 1
# cluster = [5, 23, 28, 44, 57]
# population =  [21839, 138019, 68163, 216403, 28917]
# L,U = 469517 518939
# size = 1
# cluster = [17]
# population =  [473117]
# L,U = 469517 518939
# size = 6
# cluster = [32, 34, 4, 37, 9, 49, 50, 29]
# population =  [448229, 843843, 909235, 152486, 156255, 19016, 13195, 282424]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.01
# 1 	 9790553095.33 	 0.00
# 2 	 9537957493.45 	 0.00
# 3 	 9439656275.06 	 0.00
# 4 	 9431639824.27 	 0.00
# 5 	 9431225336.47 	 0.00
# 6 	 9431224704.24 	 0.00
# 7 	 9431224704.24 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [6087, 368, 7845, 5838, 4925, 189]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 4766 rows, 4080 columns and 26910 nonzeros
# Model fingerprint: 0xf3f085b3
# Variable types: 2266 continuous, 1814 integer (1814 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+03, 8e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 3460 rows and 3078 columns
# Presolve time: 0.10s
# Presolved: 1306 rows, 1002 columns, 6009 nonzeros
# Variable types: 0 continuous, 1002 integer (999 binary)
#
# Root relaxation: objective 9.459910e+09, 229 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9.4599e+09    0   24          - 9.4599e+09      -     -    0s
# H    0     0                    9.523815e+09 9.4599e+09  0.67%     -    0s
#
# Explored 1 nodes (229 simplex iterations) in 0.13 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.52381e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.523814780045e+09, best bound 9.459910324923e+09, gap 0.6710%
# size = 11
# cluster = [19, 53]
# population =  [3186989, 2181654]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.28
# 1 	 3569395240.53 	 0.01
# 2 	 1770875329.95 	 0.01
# 3 	 1491027877.96 	 0.01
# 4 	 1467793976.93 	 0.01
# 5 	 1465799991.54 	 0.01
# 6 	 1465331391.81 	 0.01
# 7 	 1464830008.25 	 0.00
# 8 	 1464561018.32 	 0.01
# 9 	 1464519982.94 	 0.00
# 10 	 1464514484.54 	 0.00
# 11 	 1464514484.54 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [5379, 1440, 7918, 1999, 3217, 1484, 1554, 3402, 3067, 6553, 6521]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 12971 rows, 11880 columns and 79024 nonzeros
# Model fingerprint: 0x14eeea1d
# Variable types: 5252 continuous, 6628 integer (6628 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [4e+01, 4e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 5490 rows and 5412 columns
# Presolve time: 0.14s
# Presolved: 7481 rows, 6468 columns, 41336 nonzeros
# Variable types: 0 continuous, 6468 integer (6468 binary)
#
# Root relaxation: objective 1.464656e+09, 860 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.4647e+09    0   22          - 1.4647e+09      -     -    0s
# H    0     0                    1.469310e+09 1.4647e+09  0.32%     -    0s
#
# Explored 1 nodes (862 simplex iterations) in 0.26 seconds (0.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.46931e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.469310013781e+09, best bound 1.464655979460e+09, gap 0.3167%
# size = 2
# cluster = [25, 27]
# population =  [764442, 270861]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 613169654.37 	 0.00
# 2 	 551508202.07 	 0.00
# 3 	 551463551.07 	 0.00
# 4 	 551463551.07 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [5985, 4732]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 734 rows, 488 columns and 3280 nonzeros
# Model fingerprint: 0xd6bd1fff
# Variable types: 70 continuous, 418 integer (418 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [3e+03, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 522 rows and 370 columns
# Presolve time: 0.01s
# Presolved: 212 rows, 118 columns, 886 nonzeros
# Variable types: 0 continuous, 118 integer (118 binary)
# Found heuristic solution: objective 8.669777e+08
# Found heuristic solution: objective 7.399599e+08
#
# Root relaxation: objective 6.240304e+08, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.2403e+08    0    1 7.3996e+08 6.2403e+08  15.7%     -    0s
# H    0     0                    6.270037e+08 6.2403e+08  0.47%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 6.27004e+08 7.3996e+08 8.66978e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.270037131594e+08, best bound 6.240303856822e+08, gap 0.4742%
# size = 4
# cluster = [31, 52]
# population =  [453491, 1585055]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 521759298.80 	 0.00
# 2 	 363850683.35 	 0.00
# 3 	 333603261.63 	 0.00
# 4 	 308506337.58 	 0.00
# 5 	 307070469.22 	 0.00
# 6 	 307053246.94 	 0.00
# 7 	 307045499.46 	 0.00
# 8 	 307045310.89 	 0.00
# 9 	 307045310.89 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [7976, 3365, 5549, 8294]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 2319 rows, 1852 columns and 12132 nonzeros
# Model fingerprint: 0x16bec62b
# Variable types: 300 continuous, 1552 integer (1552 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [3e+02, 8e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 606 rows and 470 columns
# Presolve time: 0.06s
# Presolved: 1713 rows, 1382 columns, 8704 nonzeros
# Variable types: 0 continuous, 1382 integer (1382 binary)
#
# Root relaxation: objective 3.070453e+08, 399 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.0705e+08    0    6          - 3.0705e+08      -     -    0s
# H    0     0                    3.173168e+08 3.0705e+08  3.24%     -    0s
#
# Explored 1 nodes (399 simplex iterations) in 0.10 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.17317e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.173168353863e+08, best bound 3.070453108949e+08, gap 3.2370%
# size = 2
# cluster = [33, 42, 16, 18, 51, 55]
# population =  [45292, 17131, 281202, 552878, 55620, 1204]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 991981988.83 	 0.00
# 2 	 988059922.23 	 0.00
# 3 	 988059922.23 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [1907, 2581]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 644 rows, 428 columns and 2818 nonzeros
# Model fingerprint: 0xe21bca2b
# Variable types: 102 continuous, 326 integer (326 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [4e+03, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 529 rows and 348 columns
# Presolve time: 0.01s
# Presolved: 115 rows, 80 columns, 492 nonzeros
# Variable types: 0 continuous, 80 integer (80 binary)
# Found heuristic solution: objective 1.021262e+09
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.02126e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.021261630979e+09, best bound 1.015451362679e+09, gap 0.5689%
# size = 1
# cluster = [36]
# population =  [488863]
# L,U = 469517 518939
# size = 7
# cluster = [20, 38]
# population =  [179702, 3298634]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.02
# 1 	 3744221689.47 	 0.01
# 2 	 2168727982.78 	 0.00
# 3 	 2162638719.72 	 0.00
# 4 	 2159049248.93 	 0.00
# 5 	 2148710013.93 	 0.00
# 6 	 2136711602.33 	 0.00
# 7 	 2129041245.50 	 0.00
# 8 	 2125225931.03 	 0.00
# 9 	 2123954585.70 	 0.00
# 10 	 2122978098.40 	 0.00
# 11 	 2122583871.39 	 0.00
# 12 	 2122517459.37 	 0.00
# 13 	 2122440497.11 	 0.00
# 14 	 2122421987.58 	 0.00
# 15 	 2122417505.19 	 0.00
# 16 	 2122417498.36 	 0.00
# 17 	 2122417498.36 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [3922, 4689, 49, 578, 4888, 4817, 4663]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 6223 rows, 5439 columns and 36470 nonzeros
# Model fingerprint: 0x02844f3f
# Variable types: 240 continuous, 5199 integer (5199 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+02, 5e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 414 rows and 338 columns
# Presolve time: 0.08s
# Presolved: 5809 rows, 5101 columns, 33149 nonzeros
# Variable types: 0 continuous, 5101 integer (5101 binary)
#
# Root relaxation: objective 2.122417e+09, 714 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.1224e+09    0   12          - 2.1224e+09      -     -    0s
# H    0     0                    2.130436e+09 2.1224e+09  0.38%     -    0s
#
# Explored 1 nodes (717 simplex iterations) in 0.16 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2.13044e+09
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.130436205490e+09, best bound 2.122417498363e+09, gap 0.3764%
# size = 1
# cluster = [39, 21]
# population =  [99633, 404739]
# L,U = 469517 518939
# size = 1
# cluster = [0, 11, 14, 15, 24, 30, 43]
# population =  [81575, 65829, 32730, 102241, 211632, 19790, 3236]
# L,U = 469517 518939
# size = 1
# cluster = [1, 46]
# population =  [64209, 439035]
# L,U = 469517 518939
# size = 3
# cluster = [41, 54]
# population =  [262321, 1165927]
# L,U = 469517 518939
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 377657862.24 	 0.00
# 2 	 214743468.82 	 0.00
# 3 	 213922008.30 	 0.00
# 4 	 213397048.25 	 0.00
# 5 	 213136209.70 	 0.00
# 6 	 213013751.08 	 0.00
# 7 	 212718315.23 	 0.00
# 8 	 212627784.59 	 0.00
# 9 	 212593210.74 	 0.00
# 10 	 212593210.74 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [2111, 1326, 639]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1223 rows, 915 columns and 6102 nonzeros
# Model fingerprint: 0x89df180f
# Variable types: 126 continuous, 789 integer (789 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [2e+03, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+05]
# Presolve removed 321 rows and 222 columns
# Presolve time: 0.02s
# Presolved: 902 rows, 693 columns, 4391 nonzeros
# Variable types: 0 continuous, 693 integer (693 binary)
#
# Root relaxation: objective 2.125932e+08, 151 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.1259e+08    0    4          - 2.1259e+08      -     -    0s
# H    0     0                    2.128915e+08 2.1259e+08  0.14%     -    0s
#
# Explored 1 nodes (151 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2.12892e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.128915416135e+08, best bound 2.125932107385e+08, gap 0.1401%
# size = 1
# cluster = [2, 6, 7, 26, 45, 47, 48]
# population =  [136463, 27743, 8700, 182155, 16112, 91601, 44076]
# L,U = 469517 518939
# **********************************
# State: CO district_type: SH
# **********************************

# %%
print('state  district_type  splits_LB  splits_UB  gap')
for (state, district_type) in results.keys():
    splits_LB = results[state,district_type]['k'] - clusterings[state,district_type]['cluster_UB']
    splits_UB = results[state,district_type]['splits_UB'] 
    print(state,district_type, splits_LB, splits_UB, splits_UB-splits_LB)

# %%
for district_type in ['CD', 'SS', 'SH']:
    print("results for",district_type,":")
    print("state |C| k L U obvious_LB max_clusters split_LB min_splits enacted_splits")
    for state in states:
        if (state, district_type) in results.keys():
            s = state
            t = district_type
            print(state,end=' & ')
            print(results[s,t]['counties'],end=' & ')
            print(results[s,t]['k'],end=' & ')
            print(results[s,t]['L'],end=' & ')
            print(results[s,t]['U'],end=' & ')
            print(results[s,t]['obvious_LB'],end=' & ')
            print(results[s,t]['num_clusters'],end=' & ')
            print(results[s,t]['splits_LB'],end=' & ')
            print(results[s,t]['splits_UB'],end=' & ')
            print('??\\\\')  # number of enacted splits
            
    print("\n\n")
