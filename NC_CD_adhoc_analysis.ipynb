# %%
# Lemma. max_cluster for NC CD is either 11 or 12. 

# Theorem. max_cluster for NC CD is 11. 
# Proof idea. We show that 12 clusters is not achievable.

state = 'NC'
district_type = 'CD'

filepath = 'C:\\districting-data-2020\\'
filename = state + '_county.json'

from gerrychain import Graph
GC = Graph.from_json( filepath + filename )

# %%
# Facts:
#  1. We know that Wake and Mecklenburg County must belong to clusters of size >=2,
#     because each of their populations is more than U. 

from util import update_attributes, get_k_L_U
update_attributes(GC, state)   
(k,L,U) = get_k_L_U(GC, state, district_type)

for i in GC.nodes:
    name = GC.nodes[i]['NAME20']
    if name == 'Guilford':
        g = i
    elif name == 'Mecklenburg':
        m = i
    elif name == 'Forsyth':
        f = i
    elif name == 'Wake':
        w = i
        
print("Mecklenberg County has population:",GC.nodes[m]['TOTPOP'])
print("Wake County has population:",GC.nodes[w]['TOTPOP'])
# Out:
# Starting NC with k = 14 and deviation = 0.01
# Thus, we have L = 741943 and U = 749398
# Mecklenberg County has population: 1115482
# Wake County has population: 1129410

# %%
#  2. Further, the Wake and Mecklenburg clusters must be distinct, since otherwise 
#     they will belong to same cluster of size >= 4, since the population-weighted 
#     distance between them is more than 3*U, which leaves only k-4 = 10 size units.
#     In this case, the max number of clusters is at most 1 + 10 = 11.

import networkx as nx
DG = nx.DiGraph(GC)

for i,j in DG.edges:
    DG.edges[i,j]['weight'] = GC.nodes[i]['TOTPOP']
    
dist = nx.shortest_path_length(DG, weight='weight', source=m)
distance = dist[w] + GC.nodes[w]['TOTPOP']

print("( population-weighted distance from Mecklenburg to Wake ) / U =",distance/U)
# Out:
# ( population-weighted distance from Mecklenburg to Wake ) / U = 3.6351471447748724

# %%
# 3. So, if we are to have 12 clusters, then Wake and Mecklenburg must be in distinct size-2 clusters, 
#    and all remaining clusters must have size one.

# %%
# 4. Meanwhile, Guilford County must be in a different cluster than Wake and Mecklenburg,
#    because the population-weighted distance from Guilford to them is more than 2*U.

dist = nx.shortest_path_length(DG, weight='weight', source=g)
distance = dist[w] + GC.nodes[w]['TOTPOP']
print("( population-weighted distance from Guilford to Wake ) / U =",distance/U)

distance = dist[m] + GC.nodes[m]['TOTPOP']
print("( population-weighted distance from Guilford to Mecklenburg ) / U =",distance/U)
# Out:
# ( population-weighted distance from Guilford to Wake ) / U = 2.514858593164113
# ( population-weighted distance from Guilford to Mecklenburg ) / U = 2.742355864307084

# %%
# 5. Also, Forsyth County must be in yet another distinct cluster, by same arguments.

dist = nx.shortest_path_length(DG, weight='weight', source=f)
distance = dist[w] + GC.nodes[w]['TOTPOP']
print("( population-weighted distance from Forsyth to Wake ) / U =",distance/U)

distance = dist[m] + GC.nodes[m]['TOTPOP']
print("( population-weighted distance from Forsyth to Mecklenburg ) / U =",distance/U)

distance = dist[g] + GC.nodes[g]['TOTPOP']
print("( population-weighted distance from Forsyth to Guilford ) / U =",distance/U)
# Out:
# ( population-weighted distance from Forsyth to Wake ) / U = 2.36248428738801
# ( population-weighted distance from Forsyth to Mecklenburg ) / U = 2.29781638061484
# ( population-weighted distance from Forsyth to Guilford ) / U = 1.2328415608261565

# %%
# 6. Finally, we enumerate all possible (disjoint) clusters for
#       - Guilford of size 1
#       - Mecklenburg of size 2
#       - Forsyth of size 1
#    And show that no combination of them is compatible with getting 9 other clusters from the rest of the state.

# %%
import gurobipy as gp
from gurobipy import GRB
from separation import find_fischetti_separator

# %%
def separator_callback(m, where):
    
    if where == GRB.Callback.MIPSOL:
        xval = m.cbGetSolution(m._x)
        DG = m._DG
        b = m._root
        
        # vertices in the cluster
        S = [ v for v in DG.nodes if xval[v] > 0.5 ]
            
        for component in nx.strongly_connected_components( DG.subgraph(S) ):

            if b in component: 
                continue

            # find some vertex "a" that has largest population in this component
            maxp = max( DG.nodes[v]['TOTPOP'] for v in component )
            a = [ v for v in component if DG.nodes[v]['TOTPOP'] == maxp ][0]

            # get minimal a,b-separator and add lazy cut
            C = find_fischetti_separator(DG, component, b)
            m.cbLazy( m._x[a] <= gp.quicksum( m._x[c] for c in C) )

# %%
def enumerate_clusters_of_given_size(DG, L, U, root, size):
    
    m = gp.Model()
    m.Params.OutputFlag = 0
    
    m._x = m.addVars(DG.nodes, vtype=GRB.BINARY)
    m._x[root].LB = 1
    
    # population balance
    m.addConstr( gp.quicksum( DG.nodes[i]['TOTPOP'] * m._x[i] for i in DG.nodes ) >= size * L )
    m.addConstr( gp.quicksum( DG.nodes[i]['TOTPOP'] * m._x[i] for i in DG.nodes ) <= size * U )
    
    # No objective
    m.setObjective( 0.0, GRB.MINIMIZE )
    
    # Find the N best solutions
    N = 1000000
    m.Params.PoolSearchMode = 2 # finds N best solutions
    m.Params.PoolSolutions = N

    # Solve
    m.Params.IntFeasTol = 1e-7
    m.Params.FeasibilityTol = 1e-7
    m.Params.LazyConstraints = 1
    m._DG = DG
    m._root = root
    m._callback = separator_callback
    m.optimize(m._callback)
    
    # retrieve clusters
    clusters = list()

    for sol in range(m.SolCount):
        m.Params.SolutionNumber = sol
        cluster = [ i for i in DG.nodes if m._x[i].Xn > 0.5 ]
        clusters.append(cluster)

    #print("Number of clusters =",len(clusters)) 
    return clusters

# %%
from cluster import is_within_window 

# Do all components of GC have a population that is within 
#   an integer multiple of the population balance window?
def ok(GC, L, U, k, cluster):
    set_cluster = set(cluster)
    complement = [ i for i in GC.nodes if i not in set_cluster ]
    for component in nx.connected_components( GC.subgraph(complement) ):
        population = sum( GC.nodes[i]['TOTPOP'] for i in component )
        if not is_within_window(population, L, U):
            return False
    return True

# Only keep clusters for which GC-cluster has components with 'good' population
def filter_clusters(GC, L, U, k, clusters):
    filtered_clusters = list()
    for cluster in clusters:
        if ok(GC, L, U, k, cluster):
            filtered_clusters.append(cluster)
    return filtered_clusters

# %%
clusterings = list()
            
# Guilford clusters
gclusters = enumerate_clusters_of_given_size(DG, L, U, root=g, size=1)

for gcluster in gclusters:

    # Mecklenburg clusters
    Vm = [ i for i in GC.nodes if i not in gcluster ]
    mclusters = enumerate_clusters_of_given_size(DG.subgraph(Vm), L, U, root=m, size=2)
    mclusters = filter_clusters(GC.subgraph(Vm), L, U, k-1, mclusters)                                         

    for mcluster in mclusters:

        # Forsyth clusters
        Vf = [ i for i in GC.nodes if i not in gcluster + mcluster ]
        fclusters = enumerate_clusters_of_given_size(DG.subgraph(Vf), L, U, root=f, size=1)
        fclusters = filter_clusters(GC.subgraph(Vf), L, U, k-3, fclusters)      

        for fcluster in fclusters:
            clusterings.append( [gcluster, mcluster, fcluster] )

print("Guilford cluster, Mecklenburg cluster, Forsyth cluster")
for p in range(len(clusterings)):
    clustering = clusterings[p]
    print("Possible clustering #",p,"is",clustering)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-27
# Guilford cluster, Mecklenburg cluster, Forsyth cluster
# Possible clustering # 0 is [[5, 44, 53, 76], [23, 32, 62, 74], [4, 29, 33, 34, 48, 66, 78, 80, 81, 84, 86, 89]]
# Possible clustering # 1 is [[5, 44, 53, 76], [23, 32, 62, 74], [29, 33, 34, 48, 63, 78, 80, 81, 84, 86, 89]]
# Possible clustering # 2 is [[5, 44, 53, 76], [15, 32, 35, 38, 62], [23, 34, 37, 70, 78, 80, 89]]
# Possible clustering # 3 is [[5, 44, 53, 76], [15, 32, 35, 38, 62], [34, 48, 59, 78, 80, 84, 89]]
# Possible clustering # 4 is [[5, 44, 53, 76], [15, 32, 35, 38, 62], [23, 34, 50, 59, 80, 89]]
# Possible clustering # 5 is [[5, 44, 53, 76], [15, 32, 35, 62, 81], [23, 34, 50, 59, 72, 89, 99]]
# Possible clustering # 6 is [[5, 44, 53, 76], [32, 70, 74], [4, 29, 33, 34, 48, 66, 78, 80, 81, 84, 86, 89]]
# Possible clustering # 7 is [[5, 44, 53, 76], [32, 70, 74], [34, 35, 38, 63, 78, 80, 81, 89]]
# Possible clustering # 8 is [[5, 44, 53, 76], [32, 70, 74], [29, 34, 35, 38, 48, 78, 80, 84, 86, 89]]
# Possible clustering # 9 is [[5, 44, 53, 76], [32, 70, 74], [29, 33, 34, 48, 63, 78, 80, 81, 84, 86, 89]]
# Possible clustering # 10 is [[5, 44, 53, 76], [32, 70, 74], [34, 35, 48, 63, 78, 80, 84, 89]]

# %%
from cluster import max_cluster_main

# for each possible clustering combination for Guilford/Mecklenburg/Forsyth do:
for p in range(len(clusterings)):
    
    clustering = clusterings[p]
    print("Trying possible clustering #",p,"which is",clustering)
    
    [gcluster, mcluster, fcluster] = clustering
    used = gcluster + mcluster + fcluster
    VC = [ i for i in GC.nodes if i not in used ]
    
    # possible to get 9 clusters from the rest of the state?
    
    # first, try a 10-min time limit
    results = max_cluster_main(GC.subgraph(VC), L, U, k=10, max_t=2, restarts=1, time_limit=600)
    
    if results['cluster_UB'] >= 8.5:
        
        # next, try a 1-day time limit
        results = max_cluster_main(GC.subgraph(VC), L, U, k=10, max_t=2, restarts=1, time_limit=24*3600)
        
        if results['cluster_UB'] >= 8.5:
            
            print("It seems possible to get 9 other clusters!!!")
            print("We have clusters:",results['clusters'])
            print("With sizes:",results['sizes'])
            break
# Out:
# Trying possible clustering # 0 which is [[5, 44, 53, 76], [23, 32, 62, 74], [4, 29, 33, 34, 48, 66, 78, 80, 81, 84, 86, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 3, 3,
# carved LB = 6
# carved cut edges = 52
# cut edges -= 4
# clusters += 1 ( w/ cut edges += 28 )
# cut edges -= 15
# t = 2 -> #clusters, #cut edges = 7 61
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 7 61
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 22288 rows, 34800 columns and 142377 nonzeros
# Model fingerprint: 0xd01a45b9
# Variable types: 28320 continuous, 6480 integer (6400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 7 (0.06s)
# Loaded user MIP start with objective 7
#
# Presolve removed 16761 rows and 26302 columns
# Presolve time: 0.36s
# Presolved: 5527 rows, 8498 columns, 34983 nonzeros
# Variable types: 6712 continuous, 1786 integer (1761 binary)
#
# Root relaxation: objective 9.000000e+00, 4395 iterations, 0.53 seconds (0.69 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  158    7.00000    9.00000  28.6%     -    1s
#      0     0    9.00000    0  256    7.00000    9.00000  28.6%     -    2s
#      0     0    9.00000    0  222    7.00000    9.00000  28.6%     -    2s
#      0     0    9.00000    0  148    7.00000    9.00000  28.6%     -    4s
#      0     0    9.00000    0  131    7.00000    9.00000  28.6%     -    4s
#      0     0    9.00000    0  134    7.00000    9.00000  28.6%     -    5s
#      0     0    9.00000    0  108    7.00000    9.00000  28.6%     -    6s
#      0     0    9.00000    0  107    7.00000    9.00000  28.6%     -    7s
#      0     0    9.00000    0  237    7.00000    9.00000  28.6%     -    8s
#      0     0    9.00000    0  172    7.00000    9.00000  28.6%     -   10s
#      0     0    9.00000    0  168    7.00000    9.00000  28.6%     -   10s
#      0     0    9.00000    0  176    7.00000    9.00000  28.6%     -   12s
#      0     0    9.00000    0  145    7.00000    9.00000  28.6%     -   13s
#      0     2    9.00000    0  145    7.00000    9.00000  28.6%     -   14s
#      1     4    9.00000    1  145    7.00000    9.00000  28.6%  2158   15s
#     67    75    9.00000   11  109    7.00000    9.00000  28.6%   815   20s
#    176   135    9.00000   11  151    7.00000    9.00000  28.6%   662   27s
#    293   205 infeasible   16         7.00000    9.00000  28.6%   641   31s
#    473   278 infeasible   32         7.00000    9.00000  28.6%   588   40s
#    527   283    9.00000   16  137    7.00000    9.00000  28.6%   577   51s
#    716   428    9.00000   10  178    7.00000    9.00000  28.6%   571   57s
#    843   553    9.00000   32   96    7.00000    9.00000  28.6%   571   62s
#   1126   602    8.35363   35  174    7.00000    9.00000  28.6%   554   67s
#   1330   657 infeasible   28         7.00000    9.00000  28.6%   576   73s
#   1513   714    8.36080   29  148    7.00000    9.00000  28.6%   606   79s
#   1747   791     cutoff   12         7.00000    9.00000  28.6%   610   85s
#   1970   833 infeasible   29         7.00000    9.00000  28.6%   609   97s
#   2098   835    8.00000   35  121    7.00000    9.00000  28.6%   601  101s
#   2101   837    9.00000   15  228    7.00000    9.00000  28.6%   600  105s
#   2106   841    9.00000   35  280    7.00000    9.00000  28.6%   599  110s
#   2110   846    9.00000   12  144    7.00000    9.00000  28.6%  31.5  117s
#   2116   852    9.00000   14   92    7.00000    9.00000  28.6%  34.8  120s
#   2132   853    9.00000   16  120    7.00000    9.00000  28.6%  40.3  125s
#   2148   844    9.00000   16   81    7.00000    9.00000  28.6%  51.4  130s
#   2178   836 infeasible   19         7.00000    9.00000  28.6%  63.6  135s
#   2230   827    8.52651   20  135    7.00000    9.00000  28.6%  82.5  140s
#   2251   832    9.00000   23  141    7.00000    9.00000  28.6%  94.5  145s
#   2324   807    9.00000   31  147    7.00000    9.00000  28.6%   117  151s
#   2387   812    9.00000   36  104    7.00000    9.00000  28.6%   138  156s
#   2480   745    8.00000   30   54    7.00000    9.00000  28.6%   162  160s
#   2589   697 infeasible   23         7.00000    9.00000  28.6%   188  165s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 15
#   Implied bound: 2
#   Clique: 8
#   MIR: 44
#   Flow cover: 189
#   Zero half: 1
#   Network: 154
#   Relax-and-lift: 3
#
# Explored 2697 nodes (1877134 simplex iterations) in 169.57 seconds (250.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# ********************************************************
# MIP gives #clusters, #cut edges = 7 61
# ********************************************************
#
# Trying possible clustering # 1 which is [[5, 44, 53, 76], [23, 32, 62, 74], [29, 33, 34, 48, 63, 78, 80, 81, 84, 86, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 2, 4,
# carved LB = 6
# carved cut edges = 55
# cut edges -= 2
# cut edges -= 5
# t = 2 -> #clusters, #cut edges = 6 48
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 6 48
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 22825 rows, 35964 columns and 146793 nonzeros
# Model fingerprint: 0xcda096c7
# Variable types: 29322 continuous, 6642 integer (6561 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 6 (0.04s)
# Loaded user MIP start with objective 6
#
# Presolve removed 17098 rows and 27131 columns
# Presolve time: 0.37s
# Presolved: 5727 rows, 8833 columns, 36343 nonzeros
# Variable types: 6975 continuous, 1858 integer (1832 binary)
#
# Root relaxation: objective 9.000000e+00, 4380 iterations, 0.73 seconds (0.79 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  208    6.00000    9.00000  50.0%     -    2s
#      0     0    9.00000    0  245    6.00000    9.00000  50.0%     -    2s
#      0     0    9.00000    0  213    6.00000    9.00000  50.0%     -    3s
#      0     0    9.00000    0  191    6.00000    9.00000  50.0%     -    4s
#      0     0    9.00000    0  179    6.00000    9.00000  50.0%     -    4s
#      0     0    9.00000    0  141    6.00000    9.00000  50.0%     -    6s
#      0     0    9.00000    0  137    6.00000    9.00000  50.0%     -    6s
#      0     0    9.00000    0  184    6.00000    9.00000  50.0%     -    7s
#      0     0    9.00000    0  196    6.00000    9.00000  50.0%     -    8s
#      0     0    9.00000    0  192    6.00000    9.00000  50.0%     -   10s

#
# Cutting planes:
#   Gomory: 5
#   Cover: 12
#   Implied bound: 5
#   Clique: 2
#   MIR: 48
#   StrongCG: 1
#   Flow cover: 156
#   GUB cover: 1
#   Zero half: 1
#   Network: 137
#   RLT: 2
#   Relax-and-lift: 4
#
# Explored 11030 nodes (5908041 simplex iterations) in 306.06 seconds (392.97 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# ********************************************************
# MIP gives #clusters, #cut edges = 7 78
# ********************************************************
#
# cut edges -= 2
# t = 2 -> #clusters, #cut edges = 7 76
# Trying possible clustering # 2 which is [[5, 44, 53, 76], [15, 32, 35, 38, 62], [23, 34, 37, 70, 78, 80, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 2, 2, 2,
# carved LB = 7
# carved cut edges = 58
# cut edges -= 1
# cut edges -= 1
# t = 2 -> #clusters, #cut edges = 7 56
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 7 56
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24256 rows, 37548 columns and 153345 nonzeros
# Model fingerprint: 0x975e2fba
# Variable types: 30408 continuous, 7140 integer (7056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 7 (0.06s)
# Loaded user MIP start with objective 7
#
# Presolve removed 17958 rows and 27991 columns
# Presolve time: 0.41s
# Presolved: 6298 rows, 9557 columns, 39386 nonzeros
# Variable types: 7483 continuous, 2074 integer (2042 binary)
#
# Root relaxation: objective 9.000000e+00, 5403 iterations, 0.91 seconds (1.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  111    7.00000    9.00000  28.6%     -    2s
#      0     0    9.00000    0  213    7.00000    9.00000  28.6%     -    3s
#      0     0    9.00000    0  169    7.00000    9.00000  28.6%     -    3s
#      0     0    9.00000    0  155    7.00000    9.00000  28.6%     -    6s
#      0     0    9.00000    0  143    7.00000    9.00000  28.6%     -    6s
#      0     0    9.00000    0  187    7.00000    9.00000  28.6%     -    7s
#      0     0    9.00000    0  180    7.00000    9.00000  28.6%     -    8s
#      0     0    9.00000    0  148    7.00000    9.00000  28.6%     -   10s
#      0     0    9.00000    0   97    7.00000    9.00000  28.6%     -   11s
#      0     2    9.00000    0   97    7.00000    9.00000  28.6%     -   12s
#     32    42    8.82842    6  115    7.00000    9.00000  28.6%  1081   15s
#     91   123    8.82842   12   95    7.00000    9.00000  28.6%   730   21s
#    264   174 infeasible   21         7.00000    9.00000  28.6%   545   30s
#    531   273 infeasible   25         7.00000    9.00000  28.6%   425   43s
#    678   303 infeasible   35         7.00000    9.00000  28.6%   399   48s
#    731   400    8.78700   33   71    7.00000    9.00000  28.6%   415   50s
#   1522   645 infeasible   37         7.00000    9.00000  28.6%   338   56s
#  13236  1546    8.00000   46   76    7.00000    8.22771  17.5%   520  410s
#  13490  1493 infeasible   35         7.00000    8.00000  14.3%   518  427s
#  14817  1472 infeasible   27         7.00000    8.00000  14.3%   502  441s
#  16108  1497    8.00000   27   61    7.00000    8.00000  14.3%   487  453s
#  16909  1551 infeasible   28         7.00000    8.00000  14.3%   480  465s
#  17823  1546 infeasible   30         7.00000    8.00000  14.3%   474  476s
#  18794  1575    8.00000   30   65    7.00000    8.00000  14.3%   467  484s
#  19796  1573 infeasible   29         7.00000    8.00000  14.3%   459  492s
#  20600  1526 infeasible   35         7.00000    8.00000  14.3%   455  595s
#  21505  1514    8.00000   38  121    7.00000    8.00000  14.3%   455  600s
#
# Cutting planes:
#   Cover: 9
#   Implied bound: 4
#   MIR: 48
#   StrongCG: 1
#   Flow cover: 140
#   GUB cover: 1
#   Zero half: 1
#   Network: 91
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 21853 nodes (9991123 simplex iterations) in 600.04 seconds (732.27 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7
#
# Time limit reached
# Best objective 7.000000000000e+00, best bound 8.000000000000e+00, gap 14.2857%
# ********************************************************
# MIP gives #clusters, #cut edges = 7 56
# ********************************************************
#
# Trying possible clustering # 3 which is [[5, 44, 53, 76], [15, 32, 35, 38, 62], [34, 48, 59, 78, 80, 84, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 6,
# carved LB = 5
# carved cut edges = 43
# clusters += 1 ( w/ cut edges += 8 )
# t = 2 -> #clusters, #cut edges = 6 51
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 6 51
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24298 rows, 38220 columns and 155602 nonzeros
# Model fingerprint: 0xc193da49
# Variable types: 31080 continuous, 7140 integer (7056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 6 (0.05s)
# Loaded user MIP start with objective 6
#
# Presolve removed 17831 rows and 28530 columns
# Presolve time: 0.40s
# Presolved: 6467 rows, 9690 columns, 40222 nonzeros
# Variable types: 7537 continuous, 2153 integer (2104 binary)
#
# Root relaxation: objective 9.000000e+00, 4436 iterations, 0.67 seconds (0.84 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  152    6.00000    9.00000  50.0%     -    1s
#      0     0    9.00000    0  256    6.00000    9.00000  50.0%     -    2s
#      0     0    9.00000    0  219    6.00000    9.00000  50.0%     -    2s
#      0     0    9.00000    0  175    6.00000    9.00000  50.0%     -    5s
#      0     0    9.00000    0  137    6.00000    9.00000  50.0%     -    5s
#      0     0    9.00000    0  166    6.00000    9.00000  50.0%     -    6s
#      0     0    9.00000    0  112    6.00000    9.00000  50.0%     -    7s
#      0     0    9.00000    0  165    6.00000    9.00000  50.0%     -    8s
#      0     0    9.00000    0  165    6.00000    9.00000  50.0%     -    8s
#      0     2    9.00000    0  154    6.00000    9.00000  50.0%     -   10s
#     72    94    8.88239   15  154    6.00000    9.00000  50.0%   781   15s
#    107   122    8.88239   21  145    6.00000    9.00000  50.0%   787   22s
#   8567  1778 infeasible   27         6.00000    9.00000  50.0%   534  380s
#   8936  1891    7.00000   40   84    6.00000    9.00000  50.0%   539  391s
#   9331  1984    8.00000   23  147    6.00000    9.00000  50.0%   548  403s
#   9703  2061    8.61999   28   60    6.00000    9.00000  50.0%   557  415s
#   9991  2149 infeasible   33         6.00000    9.00000  50.0%   560  426s
#  10305  2248    8.00000   24  112    6.00000    9.00000  50.0%   572  441s
#  10780  2302    8.70161   31  176    6.00000    9.00000  50.0%   584  452s
#  10991  2403    8.60481   29  103    6.00000    9.00000  50.0%   586  466s
#  11440  2441 infeasible   35         6.00000    9.00000  50.0%   593  478s
#  11689  2524    9.00000   33  131    6.00000    9.00000  50.0%   596  497s
#  11996  2532    7.95624   35  121    6.00000    9.00000  50.0%   602  513s
#  12626  2567    8.91543   33  106    6.00000    8.92075  48.7%   609  528s
#  13249  2570    8.00000   27   44    6.00000    8.69968  45.0%   614  539s
#  13443  2687    7.00000   28  128    6.00000    8.63552  43.9%   614  553s
#  13892  2728    8.00000   26  116    6.00000    8.59184  43.2%   621  569s
#  14379  2787 infeasible   46         6.00000    8.45977  41.0%   623  585s
#  14992  2837    7.00000   36   55    6.00000    8.29793  38.3%   626  600s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 22
#   Implied bound: 7
#   Clique: 2
#   MIR: 74
#   Flow cover: 209
#   GUB cover: 1
#   Network: 124
#   RLT: 5
#   Relax-and-lift: 5
#
# Explored 15689 nodes (11144845 simplex iterations) in 600.10 seconds (824.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Time limit reached
# Best objective 6.000000000000e+00, best bound 8.000000000000e+00, gap 33.3333%
# ********************************************************
# MIP gives #clusters, #cut edges = 6 51
# ********************************************************
#
# Trying possible clustering # 4 which is [[5, 44, 53, 76], [15, 32, 35, 38, 62], [23, 34, 50, 59, 80, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 6,
# carved LB = 5
# carved cut edges = 43
# clusters += 1 ( w/ cut edges += 17 )
# cut edges -= 4
# t = 2 -> #clusters, #cut edges = 6 56
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 6 56
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24617 rows, 38080 columns and 154737 nonzeros
# Model fingerprint: 0x8d51701d
# Variable types: 30770 continuous, 7310 integer (7225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 6 (0.06s)
# Loaded user MIP start with objective 6
#
# Presolve removed 18541 rows and 28919 columns
# Presolve time: 0.46s
# Presolved: 6076 rows, 9161 columns, 37836 nonzeros
# Variable types: 7167 continuous, 1994 integer (1962 binary)
#
# Root relaxation: objective 9.000000e+00, 4112 iterations, 0.62 seconds (0.69 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9
#   3001   492    8.00000   16  111    6.00000    8.00000  33.3%   627  144s
#   3329   512 infeasible   24         6.00000    8.00000  33.3%   634  150s
#   3584   487    7.00000   22  121    6.00000    8.00000  33.3%   636  155s
#   3733   455 infeasible   15         6.00000    8.00000  33.3%   648  160s
#   4087   495 infeasible   17         6.00000    8.00000  33.3%   625  165s
#   4531   535    7.00000   11   83    6.00000    7.69851  28.3%   622  175s
#   4856   571    7.00000   16  113    6.00000    7.48745  24.8%   612  181s
#   5447   574 infeasible   25         6.00000    7.00000  16.7%   580  191s
#   6173   511    7.00000   22  121    6.00000    7.00000  16.7%   563  199s
#   6702   397    7.00000   23  102    6.00000    7.00000  16.7%   555  207s
#   7104   252    7.00000   20  115    6.00000    7.00000  16.7%   548  215s
#   7523   129    7.00000   23  112    6.00000    7.00000  16.7%   542  223s
#   8038    84    7.00000   37  121    6.00000    7.00000  16.7%   538  231s
#   8395    33    7.00000   31   99    6.00000    7.00000  16.7%   537  239s
#   8624     0 infeasible   31         6.00000    7.00000  16.7%   537  240s
#
# Cutting planes:
#   Gomory: 7
#   Lift-and-project: 2
#   Cover: 1408
#   Implied bound: 217
#   Clique: 5
#   MIR: 180
#   StrongCG: 9
#   Flow cover: 458
#   GUB cover: 1
#   Inf proof: 44
#   Zero half: 1
#   Network: 400
#   RLT: 12
#   Relax-and-lift: 13
#
# Explored 8679 nodes (4723638 simplex iterations) in 241.03 seconds (324.15 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# ********************************************************
# MIP gives #clusters, #cut edges = 6 56
# ********************************************************
#
# Trying possible clustering # 5 which is [[5, 44, 53, 76], [15, 32, 35, 62, 81], [23, 34, 50, 59, 72, 89, 99]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 3, 1, 1, 1, 1, 1, 2,
# carved LB = 7
# carved cut edges = 54
# t = 2 -> #clusters, #cut edges = 7 54
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 7 54
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24164 rows, 38220 columns and 154638 nonzeros
# Model fingerprint: 0xc6bb1ca8
# Variable types: 31080 continuous, 7140 integer (7056 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 7 (0.06s)
# Loaded user MIP start with objective 7
#
# Presolve removed 18088 rows and 28966 columns
# Presolve time: 0.49s
# Presolved: 6076 rows, 9254 columns, 37994 nonzeros
# Variable types: 7294 continuous, 1960 integer (1932 binary)
#
# Root relaxation: objective 9.000000e+00, 4515 iterations, 0.65 seconds (0.78 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9
#  10938   154    8.00000   56   93    7.00000    8.00000  14.3%   419  266s
#  11122   116    8.00000   56  127    7.00000    8.00000  14.3%   424  271s
#  11337    68    8.00000   57  121    7.00000    8.00000  14.3%   431  276s
#  11467    29 infeasible   57         7.00000    8.00000  14.3%   438  281s
#  11836    14 infeasible   59         7.00000    8.00000  14.3%   439  288s
#  11899     0    8.00000   58   71    7.00000    8.00000  14.3%   439  290s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 117
#   Implied bound: 8
#   Projected implied bound: 2
#   Clique: 1
#   MIR: 370
#   StrongCG: 21
#   Flow cover: 825
#   GUB cover: 3
#   Inf proof: 25
#   Zero half: 18
#   Network: 269
#   RLT: 4
#   Relax-and-lift: 21
#
# Explored 11967 nodes (5299099 simplex iterations) in 290.30 seconds (404.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# ********************************************************
# MIP gives #clusters, #cut edges = 7 54
# ********************************************************
#
# Trying possible clustering # 6 which is [[5, 44, 53, 76], [32, 70, 74], [4, 29, 33, 34, 48, 66, 78, 80, 81, 84, 86, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 1, 5,
# carved LB = 6
# carved cut edges = 51
# clusters += 1 ( w/ cut edges += 9 )
# t = 2 -> #clusters, #cut edges = 7 60
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 7 60
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 22875 rows, 36288 columns and 147912 nonzeros
# Model fingerprint: 0x0d542276
# Variable types: 29646 continuous, 6642 integer (6561 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 7 (0.06s)
# Loaded user MIP start with objective 7
#
# Presolve removed 16403 rows and 26412 columns
# Presolve time: 0.22s
# Presolved: 6472 rows, 9876 columns, 40567 nonzeros
# Variable types: 7771 continuous, 2105 integer (2076 binary)
#
# Root relaxation: objective 9.000000e+00, 4118 iterations, 0.51 seconds (0.64 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  147    7.00000    9.00000  28.6%     -    1s
#      0     0    9.00000    0  263    7.00000    9.00000  28.6%     -    2s
#      0     0    9.00000    0  168    7.00000    9.00000  28.6%     -    4s
#      0     0    9.00000    0  156    7.00000    9.00000  28.6%     -    5s
#      0     0    9.00000    0  130    7.00000    9.00000  28.6%     -    6s
#      0     0    9.00000    0  137    7.00000    9.00000  28.6%     -    6s
#      0     0    9.00000    0  139    7.00000    9.00000  28.6%     -    7s
#      0     0    9.00000    0  140    7.00000    9.00000  28.6%     -    8s
#      0     0    9.00000    0  116    7.00000    9.00000  28.6%     -    9s
#      0     0    9.00000    0  166    7.00000    9.00000  28.6%     -   10s
#      0     0    9.00000    0  124    7.00000    9.00000  28.6%     -   13s
#      0     0    9.00000    0  112    7.00000    9.00000  28.6%     -   13s
#      0     2    9.00000    0   98    7.00000    9.00000  28.6%     -   16s
#     84    69    9.00000   28  152    7.00000    9.00000  28.6%   773   22s
#    135   129    8.83960   34   94    7.00000    9.00000  28.6%   759   26s
#    310   289    8.83960   35   85    7.00000    9.00000  28.6%   574   32s
#    499   331    8.63858   29  159    7.00000    9.00000  28.6%   545   36s
#    605   467    8.00000   32  143    7.00000    9.00000  28.6%   557   41s
#    848   617 infeasible   45         7.00000    9.00000  28.6%   549   48s
#   1107   618    9.00000   28  112    7.00000    9.00000  28.6%   545   51s
#   1110   620    8.00000   27  119    7.00000    9.00000  28.6%   544   55s
#   1114   623    9.00000   28  180    7.00000    9.00000  28.6%   542   60s
#   1118   625    9.00000   35  139    7.00000    9.00000  28.6%   540   65s
#   1120   627    9.00000   28  181    7.00000    9.00000  28.6%   539   70s
#   1123   632    9.00000   12  115    7.00000    9.00000  28.6%  83.3   75s
#   1129   637    9.00000   14   95    7.00000    9.00000  28.6%  89.2   81s
#   1145   638    9.00000   16  139    7.00000    9.00000  28.6%   109   85s
#   1181   664    9.00000   19  119    7.00000    9.00000  28.6%   123   91s
#   1228   689    9.00000   21  206    7.00000    9.00000  28.6%   142   98s
#   1255   704    9.00000   22  121    7.00000    9.00000  28.6%   149  103s
#   1315   709    8.00000   26  110    7.00000    9.00000  28.6%   172  107s
#   1420   709 infeasible   36         7.00000    9.00000  28.6%   217  110s
#   1507   697 infeasible   53         7.00000    9.00000  28.6%   236  115s
#   1712   726 infeasible   43         7.00000    9.00000  28.6%   281  122s
#   1795   797    8.00000   53  119    7.00000    9.00000  28.6%   303  126s
#   2025   738    9.00000   27  150    7.00000    9.00000  28.6%   321  131s
# ...
#   RLT: 1
#   Relax-and-lift: 4
#
# Explored 22527 nodes (11407818 simplex iterations) in 600.03 seconds (875.92 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7
#
# Time limit reached
# Best objective 7.000000000000e+00, best bound 9.000000000000e+00, gap 28.5714%
# ********************************************************
# MIP gives #clusters, #cut edges = 7 60
# ********************************************************
#
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 2, 4,
# carved LB = 6
# carved cut edges = 62
# cut edges -= 1
# cut edges -= 2
# clusters += 1 ( w/ cut edges += 15 )
# clusters += 1 ( w/ cut edges += 8 )
# t = 2 -> #clusters, #cut edges = 8 82
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 8 82
# ********************************************************
#
# Set parameter TimeLimit to value 86400
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 23398 rows, 37474 columns and 152304 nonzeros
# Model fingerprint: 0xc2d3ffae
# Variable types: 30668 continuous, 6806 integer (6724 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 8 (0.05s)
# Loaded user MIP start with objective 8
#
# Presolve removed 16735 rows and 27230 columns
# Presolve time: 0.23s
# Presolved: 6663 rows, 10244 columns, 41976 nonzeros
# Variable types: 8064 continuous, 2180 integer (2148 binary)
#
# Root relaxation: objective 9.000000e+00, 5042 iterations, 0.82 seconds (1.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  206    8.00000    9.00000  12.5%     -    1s
#      0     0    9.00000    0  231    8.00000    9.00000  12.5%     -    2s
#      0     0    9.00000    0  188    8.00000    9.00000  12.5%     -    2s
#      0     0    9.00000    0   98    8.00000    9.00000  12.5%     -    4s
#      0     0    9.00000    0  110    8.00000    9.00000  12.5%     -    4s
#      0     0    9.00000    0   92    8.00000    9.00000  12.5%     -    5s
#      0     0    9.00000    0   90    8.00000    9.00000  12.5%     -    5s
#      0     0    9.00000    0  110    8.00000    9.00000  12.5%     -    6s
#      0     0    9.00000    0  143    8.00000    9.00000  12.5%     -    7s
#      0     0    9.00000    0  132    8.00000    9.00000  12.5%     -    8s
#      0     0    9.00000    0  132    8.00000    9.00000  12.5%     -    8s
#      0     2    9.00000    0  132    8.00000    9.00000  12.5%     -    9s
#      2     3    9.00000    1  132    8.00000    9.00000  12.5%   559   11s
#      5     5    9.00000    1  165    8.00000    9.00000  12.5%   223   15s
#     11     9    9.00000    1  137    8.00000    9.00000  12.5%   102   20s
#     17    13    9.00000    1  116    8.00000    9.00000  12.5%  65.7   25s
#     22    17    9.00000   16  126    8.00000    9.00000  12.5%  3436   31s
#     26    22    9.00000   18  131    8.00000    9.00000  12.5%  3111   37s
#     53    39    9.00000   22  123    8.00000    9.00000  12.5%  1941   40s
#    149   128 infeasible   35         8.00000    9.00000  12.5%   992   47s
#    288   147 infeasible   28         8.00000    9.00000  12.5%   834   50s
#    443   167    9.00000   34   74    8.00000    9.00000  12.5%   787   55s
#    529   194 infeasible   40         8.00000    9.00000  12.5%   796   69s
#    718   218    9.00000   40   57    8.00000    9.00000  12.5%   758   76s
#   1128   222    9.00000   31   91    8.00000    9.00000  12.5%   708   81s
#   1365   222    9.00000   44   28    8.00000    9.00000  12.5%   692   88s
#   1832   231    9.00000   31  113    8.00000    9.00000  12.5%   640   99s
#   1925   286    9.00000   32   65    8.00000    9.00000  12.5%   634  114s
#   2093   294    9.00000   42   91    8.00000    9.00000  12.5%   632  122s
#   2474   324 infeasible   44         8.00000    9.00000  12.5%   643  129s
#   2893   317    9.00000   31   91    8.00000    9.00000  12.5%   648  137s
#   3208   374    9.00000   38   55    8.00000    9.00000  12.5%   650  145s
#   3588   416 infeasible   51         8.00000    9.00000  12.5%   654  155s
#   4069   417    9.00000   37   70    8.00000    9.00000  12.5%   645  166s
#   4603   431    9.00000   37  131    8.00000    9.00000  12.5%   625  179s
#   4940   421 infeasible   50         8.00000    9.00000  12.5%   625  191s
#   5124   430    9.00000   37   97    8.00000    9.00000  12.5%   631  205s
#   5604   439    9.00000   38   98    8.00000    9.00000  12.5%   632  218s
#   6016   420    9.00000   47  101    8.00000    9.00000  12.5%   641  231s
#   6479   441    9.00000   32  141    8.00000    9.00000  12.5%   644  245s
#   6905   446    9.00000   37   81    8.00000    9.00000  12.5%   654  259s
#   7266   482    9.00000   37  117    8.00000    9.00000  12.5%   654  274s
#   7762   576    9.00000   34  129    8.00000    9.00000  12.5%   659  305s
#   8117   605    9.00000   64   71    8.00000    9.00000  12.5%   659  318s
#   8344   681    9.00000   57   57    8.00000    9.00000  12.5%   658  336s
#   9313   711    9.00000   39  103    8.00000    9.00000  12.5%   640  354s
#   9885   806    9.00000   42   76    8.00000    9.00000  12.5%   639  374s
#  10621   865    9.00000   48   85    8.00000    9.00000  12.5%   637  398s
#  11410   883 infeasible   56         8.00000    9.00000  12.5%   630  413s
#  12070   922    9.00000   63   50    8.00000    9.00000  12.5%   627  429s
#  12635   982    9.00000   32   92    8.00000    9.00000  12.5%   625  449s
#  13174   987    9.00000   57   82    8.00000    9.00000  12.5%   627  466s
#  13267  1021    9.00000   59  148    8.00000    9.00000  12.5%   628  484s
#  14174   986 infeasible   38         8.00000    9.00000  12.5%   631  500s
#  14976  1018    9.00000   35  126    8.00000    9.00000  12.5%   631  516s
#  15369  1057 infeasible   48         8.00000    9.00000  12.5%   630  536s
#  16122  1061 infeasible   55         8.00000    9.00000  12.5%   632  551s
#  16392  1088    9.00000   42  117    8.00000    9.00000  12.5%   632  569s
#  17217  1073    9.00000   43  104    8.00000    9.00000  12.5%   631  585s
#  17677  1120 infeasible   44         8.00000    9.00000  12.5%   635  602s
#  18434  1127    9.00000   51  112    8.00000    9.00000  12.5%   638  618s
#  19337  1074    9.00000   38  110    8.00000    9.00000  12.5%   636  633s
#  20003  1138    9.00000   29  163    8.00000    9.00000  12.5%   639  646s
#  20331  1137    9.00000   34   64    8.00000    9.00000  12.5%   646  661s
#  20873  1138    9.00000   41  132    8.00000    9.00000  12.5%   652  670s
#  20878  1141    9.00000   47  118    8.00000    9.00000  12.5%   652  675s
#  20884  1145    9.00000   22  157    8.00000    9.00000  12.5%   652  680s
#  20889  1152    9.00000   27  162    8.00000    9.00000  12.5%   655  687s
#  20903  1159    9.00000   30  105    8.00000    9.00000  12.5%   654  690s
#  20933  1194    9.00000   33  100    8.00000    9.00000  12.5%   654  695s
#  21042  1267    9.00000   42  110    8.00000    9.00000  12.5%   652  703s
#  21344  1195    9.00000   54   75    8.00000    9.00000  12.5%   648  708s
#  21580  1161 infeasible   53         8.00000    9.00000  12.5%   645  714s
#  21876  1096    9.00000   50   55    8.00000    9.00000  12.5%   642  720s
#  22357   943    9.00000   48   98    8.00000    9.00000  12.5%   636  728s
#  22586   881    9.00000   48  100    8.00000    9.00000  12.5%   631  739s
#  22750   849    9.00000   54   83    8.00000    9.00000  12.5%   630  745s
#  23096   766    9.00000   54   96    8.00000    9.00000  12.5%   625  751s
#  23788   552 infeasible   49         8.00000    9.00000  12.5%   617  757s
#  24365   375    9.00000   50  106    8.00000    9.00000  12.5%   611  762s
#  24721   391 infeasible   52         8.00000    9.00000  12.5%   608  767s
#  25088   430 infeasible   47         8.00000    9.00000  12.5%   606  778s
#  25285   456 infeasible   47         8.00000    9.00000  12.5%   604  788s
#  25479   460    9.00000   55  124    8.00000    9.00000  12.5%   604  795s
#  26096   563    9.00000   54  102    8.00000    9.00000  12.5%   598  801s
#  26693   596    9.00000   54   66    8.00000    9.00000  12.5%   595  812s
#  27127   640    9.00000   55   78    8.00000    9.00000  12.5%   591  824s
#  28234   641 infeasible   60         8.00000    9.00000  12.5%   579  838s
#  28600   687    9.00000   57  150    8.00000    9.00000  12.5%   576  851s
#  29470   754    9.00000   43   85    8.00000    9.00000  12.5%   569  862s
#  30255   835    9.00000   49  139    8.00000    9.00000  12.5%   564  875s
#
# Cutting planes:
#   Lift-and-project: 5
#   Cover: 7
#   Clique: 1
#   MIR: 26
#   StrongCG: 2
#   Flow cover: 82
#   Network: 66
#   RLT: 1
#   Relax-and-lift: 3
#
# Explored 31112 nodes (17451086 simplex iterations) in 1005.09 seconds (1291.59 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# ********************************************************
# MIP gives #clusters, #cut edges = 8 82
# ********************************************************
#
# Trying possible clustering # 10 which is [[5, 44, 53, 76], [32, 70, 74], [34, 35, 48, 63, 78, 80, 84, 89]]
# Initially, cluster_UB = 9
#
# ****************************
# Heuristic iteration # 0
# ****************************
# carved cluster sizes = 1, 1, 1, 1, 3, 3,
# carved LB = 6
# carved cut edges = 51
# cut edges -= 3
# t = 2 -> #clusters, #cut edges = 6 48
# new incumbent!
#
# ********************************************************
# After local search, # clusters, #cut edges = 6 48
# ********************************************************
#
# Set parameter TimeLimit to value 600
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24915 rows, 39780 columns and 161507 nonzeros
# Model fingerprint: 0xd7ff69e1
# Variable types: 32470 continuous, 7310 integer (7225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#
# User MIP start produced solution with objective 6 (0.10s)
# Loaded user MIP start with objective 6
#
# Presolve removed 18102 rows and 29473 columns
# Presolve time: 0.83s
# Presolved: 6813 rows, 10307 columns, 42382 nonzeros
# Variable types: 8102 continuous, 2205 integer (2172 binary)
#
# Root relaxation: objective 9.000000e+00, 5387 iterations, 1.11 seconds (1.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0  148    6.00000    9.00000  50.0%     -    4s
#      0     0    9.00000    0  254    6.00000    9.00000  50.0%     -    6s
#      0     0    9.00000    0  236    6.00000    9.00000  50.0%     -    7s
#      0     0    9.00000    0  155    6.00000    9.00000  50.0%     -   10s
#      0     0    9.00000    0  127    6.00000    9.00000  50.0%     -   11s
#      0     0    9.00000    0  203    6.00000    9.00000  50.0%     -   13s
#      0     0    9.00000    0  211    6.00000    9.00000  50.0%     -   14s
#      0     0    9.00000    0  123    6.00000    9.00000  50.0%     -   16s
#      0     0    9.00000    0  181    6.00000    9.00000  50.0%     -   16s
#      0     0    9.00000    0  159    6.00000    9.00000  50.0%     -   20s
#      0     0    9.00000    0  159    6.00000    9.00000  50.0%     -   20s
#      0     2    9.00000    0  142    6.00000    9.00000  50.0%     -   24s
#      3     8    9.00000    2  164    6.00000    9.00000  50.0%  1317   25s
# H   31    33                       7.0000000    9.00000  28.6%   943   29s
#     33    55    9.00000    9  165    7.00000    9.00000  28.6%   984   30s
#    144   124 infeasible   21         7.00000    9.00000  28.6%   749   36s
#    260   169 infeasible   38         7.00000    9.00000  28.6%   735   42s
#    356   240    8.90090   26  118    7.00000    9.00000  28.6%   754   48s
#    426   267    8.90090   32  116    7.00000    9.00000  28.6%   744   63s
#    494   351 infeasible   25         7.00000    9.00000  28.6%   714   72s
#    751   415    8.83602    4   87    7.00000    9.00000  28.6%   671   83s
#    912   446 infeasible   22         7.00000    9.00000  28.6%   678   96s
#   1013   493    9.00000   16   99    7.00000    9.00000  28.6%   669  104s
#   1226   482 infeasible   16         7.00000    9.00000  28.6%   659  111s
#   1357   523    9.00000   14  185    7.00000    9.00000  28.6%   680  118s
#   1496   522    8.81128   22  105    7.00000    9.00000  28.6%   694  125s
#   1609   578 infeasible    6         7.00000    9.00000  28.6%   696  130s
#   1723   624 infeasible   33         7.00000    9.00000  28.6%   696  135s
#   1797   648 infeasible   20         7.00000    9.00000  28.6%   710  151s
#   1861   741    9.00000   15  125    7.00000    9.00000  28.6%   712  157s
#   2000   820    8.87722   34  110    7.00000    9.00000  28.6%   708  164s
#   2142   821    8.83602   39  159    7.00000    9.00000  28.6%   708  167s
#   2144   822    9.00000   15  159    7.00000    9.00000  28.6%   707  170s
#   2145   823    8.83602   21  157    7.00000    9.00000  28.6%   707  176s
#   2147   824    8.00000   41  137    7.00000    9.00000  28.6%   706  181s
#   2149   826    8.00000   29  179    7.00000    9.00000  28.6%   706  187s
#   2151   827    8.77437   36  159    7.00000    9.00000  28.6%   705  194s
#   2152   828    8.00000   19  239    7.00000    9.00000  28.6%   705  196s
#   2154   829    8.90090   27  222    7.00000    9.00000  28.6%   704  201s
#   2155   830    8.13886   19  146    7.00000    9.00000  28.6%   704  206s
#   2157   831    8.00000   27  149    7.00000    9.00000  28.6%   703  212s
#   2159   832    8.00000   35  136    7.00000    9.00000  28.6%   703  218s
#   2161   834    8.00000   33  136    7.00000    9.00000  28.6%   702  220s
#   2164   838    9.00000   13  116    7.00000    9.00000  28.6%  50.7  225s
#   2172   839    9.00000   15  109    7.00000    9.00000  28.6%  54.9  230s
#   2184   843    9.00000   16   90    7.00000    9.00000  28.6%  61.7  235s
#   2201   840 infeasible   18         7.00000    9.00000  28.6%  70.0  240s
#   2227   841    9.00000   20  126    7.00000    9.00000  28.6%  83.2  245s
#   2264   834    9.00000   23  134    7.00000    9.00000  28.6%  97.2  251s
#   2289   824    9.00000   24  125    7.00000    9.00000  28.6%   109  258s
#   2294   829    8.76810   25  115    7.00000    9.00000  28.6%   111  260s
#   2324   829     cutoff   28         7.00000    9.00000  28.6%   120  269s
#   2331   830    8.00000   30   65    7.00000    9.00000  28.6%   121  271s
#   2399   815    8.00000   21   96    7.00000    9.00000  28.6%   141  276s
#   2487   786    9.00000   20  133    7.00000    9.00000  28.6%   168  280s
#   2591   769    8.72639   24  123    7.00000    9.00000  28.6%   197  286s
#   2745   651 infeasible   30         7.00000    8.00000  14.3%   229  292s
#
# Cutting planes:
#   Lift-and-project: 8
#   Cover: 7
#   Clique: 1
#   MIR: 43
#   Flow cover: 86
#   Inf proof: 2
#   Zero half: 1
#   Network: 57
#   Relax-and-lift: 4
#
# Explored 2931 nodes (2312662 simplex iterations) in 294.95 seconds (277.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# ********************************************************
# MIP gives #clusters, #cut edges = 7 63
# ********************************************************
#
# cut edges -= 4
# t = 2 -> #clusters, #cut edges = 7 59
