# %%
filepath = 'C:\\districting-data-2020\\'

# 1. Code takes Daryl's tract/block-level .json files and 
#    adds the lat/lon coordinates to the nodes
#    (based on the census shapefiles)
#
outfilepath1 = 'C:\\districting-data-2020-lat-lon\\'

# 2. Then connects any disconnected graphs by adding
#    a minimum length subset of edges.
#
outfilepath2 = 'C:\\districting-data-2020-conn\\'

level = 'block'   # block or tract

# %%
import geopandas as gpd
from gerrychain import Graph
import networkx as nx

# %%
state_codes = {
    'WA': '53', 'DE': '10', 'WI': '55', 'WV': '54', 'HI': '15',
    'FL': '12', 'WY': '56', 'NJ': '34', 'NM': '35', 'TX': '48',
    'LA': '22', 'NC': '37', 'ND': '38', 'NE': '31', 'TN': '47', 'NY': '36',
    'PA': '42', 'AK': '02', 'NV': '32', 'NH': '33', 'VA': '51', 'CO': '08',
    'CA': '06', 'AL': '01', 'AR': '05', 'VT': '50', 'IL': '17', 'GA': '13',
    'IN': '18', 'IA': '19', 'MA': '25', 'AZ': '04', 'ID': '16', 'CT': '09',
    'ME': '23', 'MD': '24', 'OK': '40', 'OH': '39', 'UT': '49', 'MO': '29',
    'MN': '27', 'MI': '26', 'RI': '44', 'KS': '20', 'MT': '30', 'MS': '28',
    'SC': '45', 'KY': '21', 'OR': '41', 'SD': '46'
}

# %%
import json
from networkx.readwrite import json_graph

def write_graph_to_json(graph, json_file):
    data = json_graph.adjacency_data(graph)
    with open(json_file, "w") as f:
        json.dump(data,f)
    return

# %%
from math import cos, asin, sqrt, pi

# get approximate distance between lat/long coordinates:
# https://stackoverflow.com/questions/27928/calculate-distance-between-two-latitude-longitude-points-haversine-formula?noredirect=1&lq=1
def apx_dist(lat1, lon1, lat2, lon2):
    p = pi/180
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 12.742 * asin(sqrt(a)) #2*R*asin...

# %%
for state in state_codes.keys():
    
    print("Beginning state",state,"\n")
    
    # read county graph from file; is it connected?
    countyfile = state + '_county.json'
    GC = Graph.from_json( filepath + countyfile )
    
    # read graph from file
    graphfile = state + '_' + level + '.json'
    G = Graph.from_json( filepath + graphfile )

    # read the shapefile
    shpfile = state + '_' + level + '.shp'
    df = gpd.read_file( filepath + shpfile )
    
    # add the lat/lon coordinates to graph (based on shapefile)
    geoid_to_node = { G.nodes[i]['GEOID20'] : i for i in G.nodes }
    for u in range(len(G.nodes)):
        geoid = df['GEOID20'][u]
        i = geoid_to_node[geoid]
        G.nodes[i]['INTPTLAT20'] = float( df['INTPTLAT20'][u] )
        G.nodes[i]['INTPTLON20'] = float( df['INTPTLON20'][u] )
        
    # write the lat/lon-adjusted graph to output1
    write_graph_to_json(G, outfilepath1 + graphfile)
    
    # add intra-county edges?
    nodes_in_county = { GC.nodes[c]['GEOID20'] : list() for c in GC.nodes }
    for i in G.nodes:
        geoid = G.nodes[i]['GEOID20'][0:5]
        nodes_in_county[geoid].append(i)
    
    for county in GC.nodes:
        geoid = GC.nodes[county]['GEOID20'] 
        nodes = nodes_in_county[geoid]
        G_county = G.subgraph(nodes)
        if not nx.is_connected(G_county):
            print("The nodes within",GC.nodes[county]['NAME20'],"County with geoid =",geoid,"are not connected!")
            print("Adding intra-county edges...")
            
            # if not, then connect it with least-cost edges
            components = list(nx.connected_components(G_county))
            H = nx.complete_graph(len(components))

            for c in range(len(components)):
                component = components[c]
                print("Component",c,"has this many nodes:",len(component))

            for i,j in H.edges:

                min_dist = 999999999999.0 # some large number
                min_dist_edge = None

                for u in components[i]:

                    lat1 = G.nodes[u]['INTPTLAT20']
                    lon1 = G.nodes[u]['INTPTLON20']

                    for v in components[j]:

                        lat2 = G.nodes[v]['INTPTLAT20']
                        lon2 = G.nodes[v]['INTPTLON20']

                        dist = apx_dist(lat1, lon1, lat2, lon2)

                        if dist < min_dist:
                            min_dist = dist
                            min_dist_edge = (u,v)

                H.edges[i,j]['weight'] = min_dist
                H.edges[i,j]['G_edge'] = min_dist_edge

            # find min span tree of H
            T = nx.minimum_spanning_tree(H,weight='weight')
            print("Spanning tree edges in H are =",T.edges)

            # which edges does this correspond to in G?
            edges_to_add = [ T.edges[i,j]['G_edge'] for i,j in T.edges ]
            print("Adding these edges to G =",edges_to_add)
            G.add_edges_from(edges_to_add)

            # print their GEOIDs for later reference
            added_edges_geoids = [ ( G.nodes[i]['GEOID20'], G.nodes[j]['GEOID20'] ) for i,j in edges_to_add ]
            print("Their GEOIDs are =",added_edges_geoids)

            # make sure G is now connected
            print("After adding these edges, is G_county now connected?",nx.is_connected(G_county))
            print("")
    
    # add inter-county edges?
    if nx.is_connected(G):
        
        print("Graph is connected; no need for more inter-county edges.")
        
    else:
        print("Adding inter-county edges...")
        # if not, then connect it with least-cost edges
        components = list(nx.connected_components(G))
        H = nx.complete_graph(len(components))

        for c in range(len(components)):
            component = components[c]
            print("Component",c,"has this many nodes:",len(component))

        for i,j in H.edges:

            min_dist = 999999999999.0 # some large number
            min_dist_edge = None

            for u in components[i]:

                lat1 = G.nodes[u]['INTPTLAT20']
                lon1 = G.nodes[u]['INTPTLON20']

                for v in components[j]:

                    lat2 = G.nodes[v]['INTPTLAT20']
                    lon2 = G.nodes[v]['INTPTLON20']
                    
                    dist = apx_dist(lat1, lon1, lat2, lon2)

                    if dist < min_dist:
                        min_dist = dist
                        min_dist_edge = (u,v)

            H.edges[i,j]['weight'] = min_dist
            H.edges[i,j]['G_edge'] = min_dist_edge

        # find min span tree of H
        T = nx.minimum_spanning_tree(H,weight='weight')
        print("Spanning tree edges in H are =",T.edges)

        # which edges does this correspond to in G?
        edges_to_add = [ T.edges[i,j]['G_edge'] for i,j in T.edges ]
        print("Adding these edges to G =",edges_to_add)
        G.add_edges_from(edges_to_add)

        # print their GEOIDs for later reference
        added_edges_geoids = [ ( G.nodes[i]['GEOID20'], G.nodes[j]['GEOID20'] ) for i,j in edges_to_add ]
        print("Their GEOIDs are =",added_edges_geoids)

        # make sure G is now connected
        print("After adding these edges, is G now connected?",nx.is_connected(G))
        
    print("")
    # write the lat/lon-adjusted *and connected* graph to output2
    write_graph_to_json(G, outfilepath2 + graphfile)
# Out:
# Beginning state WA
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state DE
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state WI
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state WV
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state HI
# C:\Users\buchanan\Anaconda3\lib\site-packages\gerrychain\graph\graph.py:239: UserWarning: Found islands (degree-0 nodes). Indices of islands: {1, 3, 4}
#   "Found islands (degree-0 nodes). Indices of islands: {}".format(islands)
# The nodes within Kauai County with geoid = 15007 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1331
# Component 1 has this many nodes: 4
# Component 2 has this many nodes: 9
# Spanning tree edges in H are = [(0, 2), (1, 2)]
# Adding these edges to G = [(6350, 2671), (2866, 2865)]
# Their GEOIDs are = [('150079901000014', '150070412001005'), ('150079903000001', '150070412001001')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Maui County with geoid = 15009 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1597
# Component 1 has this many nodes: 318
# Component 2 has this many nodes: 132
# Spanning tree edges in H are = [(0, 1), (1, 2)]
# Adding these edges to G = [(2274, 8276), (3194, 12793)]
# Their GEOIDs are = [('150099902000009', '150090317001014'), ('150099900000007', '150099912000001')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Honolulu County with geoid = 15003 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 7099
# Component 1 has this many nodes: 2
# Component 2 has this many nodes: 4
# Component 3 has this many nodes: 7
# Component 4 has this many nodes: 2
# Component 5 has this many nodes: 2
# Component 6 has this many nodes: 3
# Component 7 has this many nodes: 2
# Component 8 has this many nodes: 2
# Component 9 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1), (1, 6), (2, 8), (2, 7), (3, 6), (3, 4), (4, 5), (5, 9), (7, 9)]
# Adding these edges to G = [(9520, 14328), (6, 2587), (6287, 5588), (12298, 3204), (3027, 7992), (14136, 6028), (2324, 2375), (13458, 7397), (7436, 6029)]
# Their GEOIDs are = [('150030099062009', '150039812001002'), ('150039812001003', '150039812001004'), ('150039812001023', '150039812001001'), ('150039812001022', '150039812001018'), ('150039812001009', '150039812001006'), ('150039812001011', '150039812001024'), ('150039812001025', '150039812001015'), ('150039812001014', '150039812001016'), ('150039812001019', '150039812001017')]
# After adding these edges, is G_county now connected? True
#
# Adding inter-county edges...
# Component 0 has this many nodes: 7125
# Component 1 has this many nodes: 4166
# Component 2 has this many nodes: 2097
# Component 3 has this many nodes: 1344
# Spanning tree edges in H are = [(0, 2), (0, 3), (1, 2)]
# Adding these edges to G = [(3677, 8032), (9520, 13165), (1279, 9236)]
# Their GEOIDs are = [('150039900010039', '150090318011019'), ('150030099062009', '150079901000004'), ('150010218002012', '150099902000018')]
# After adding these edges, is G now connected? True
#
# Beginning state FL
#
# The nodes within Dixie County with geoid = 12029 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1369
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(130274, 294470)]
# Their GEOIDs are = [('120299701033004', '120299701033000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Monroe County with geoid = 12087 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 2878
# Component 1 has this many nodes: 6
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(75173, 307126)]
# Their GEOIDs are = [('120879725002016', '120879801001002')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state WY
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NJ
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NM
#
# The nodes within Sandoval County with geoid = 35043 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 6389
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(74988, 39472)]
# Their GEOIDs are = [('350439410001025', '350439403001000')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state TX
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state LA
#
# The nodes within West Feliciana County with geoid = 22125 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 408
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(34969, 97076)]
# Their GEOIDs are = [('221259800001015', '221259517031001')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Madison County with geoid = 22065 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1009
# Component 1 has this many nodes: 5
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(87625, 96541)]
# Their GEOIDs are = [('220659601001263', '220659601001292')]
# After adding these edges, is G_county now connected? True
#
# The nodes within St. Martin County with geoid = 22099 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1545
# Component 1 has this many nodes: 127
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(132979, 1270)]
# Their GEOIDs are = [('220990201021089', '220990210001019')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NC
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state ND
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NE
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state TN
#
# The nodes within Dickson County with geoid = 47043 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1824
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(35894, 170789)]
# Their GEOIDs are = [('470430602012025', '470430602012051')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Davidson County with geoid = 47037 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 9096
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(18891, 119716)]
# Their GEOIDs are = [('470370156351001', '470370156351000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Tipton County with geoid = 47167 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1168
# Component 1 has this many nodes: 13
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(93884, 155602)]
# Their GEOIDs are = [('471670401001007', '471670401001025')]
# After adding these edges, is G_county now connected? True
#
# The nodes within White County with geoid = 47185 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1007
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(164158, 172620)]
# Their GEOIDs are = [('471859350001067', '471859350001075')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Loudon County with geoid = 47105 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 2027
# Component 1 has this many nodes: 2
# Component 2 has this many nodes: 2
# Component 3 has this many nodes: 2
# Spanning tree edges in H are = [(0, 2), (0, 1), (0, 3)]
# Adding these edges to G = [(953, 59344), (28996, 107009), (170148, 174982)]
# Their GEOIDs are = [('471050607002058', '471050607002103'), ('471050607002072', '471050607002105'), ('471050607001104', '471050607001109')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NY
# C:\Users\buchanan\Anaconda3\lib\site-packages\gerrychain\graph\graph.py:239: UserWarning: Found islands (degree-0 nodes). Indices of islands: {123738, 63261}
#   "Found islands (degree-0 nodes). Indices of islands: {}".format(islands)
# The nodes within New York County with geoid = 36061 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 4041
# Component 1 has this many nodes: 1
# Component 2 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1), (1, 2)]
# Adding these edges to G = [(132757, 123738), (123738, 63261)]
# Their GEOIDs are = [('360610319000001', '360610001001000'), ('360610001001000', '360610001001001')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state PA
#
# The nodes within Chester County with geoid = 42029 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 9726
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(72374, 89824)]
# Their GEOIDs are = [('420293111002044', '420293031002021')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state AK
#
# The nodes within Bethel County with geoid = 02050 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1000
# Component 1 has this many nodes: 86
# Component 2 has this many nodes: 4
# Component 3 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1), (1, 2), (2, 3)]
# Adding these edges to G = [(8182, 1803), (4474, 23102), (23102, 15319)]
# Their GEOIDs are = [('020500001001052', '020500001001095'), ('020500001001113', '020500001001062'), ('020500001001062', '020500001001160')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Dillingham County with geoid = 02070 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 309
# Component 1 has this many nodes: 2
# Component 2 has this many nodes: 3
# Spanning tree edges in H are = [(0, 2), (1, 2)]
# Adding these edges to G = [(28249, 12337), (8206, 12337)]
# Their GEOIDs are = [('020700001001076', '020700001001270'), ('020700001001241', '020700001001270')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Aleutians East County with geoid = 02013 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 73
# Component 1 has this many nodes: 495
# Component 2 has this many nodes: 33
# Component 3 has this many nodes: 2
# Component 4 has this many nodes: 2
# Component 5 has this many nodes: 3
# Component 6 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1), (1, 4), (1, 6), (1, 3), (1, 5), (1, 2)]
# Adding these edges to G = [(11247, 27240), (24987, 24512), (8908, 15315), (4931, 24587), (16978, 2716), (27091, 5637)]
# Their GEOIDs are = [('020130001001213', '020130001001132'), ('020130001002183', '020130001002200'), ('020130001001068', '020130001001291'), ('020130001001001', '020130001001289'), ('020130001003104', '020130001003111'), ('020130001002194', '020130001001279')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Nome County with geoid = 02180 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 799
# Component 1 has this many nodes: 39
# Component 2 has this many nodes: 2
# Component 3 has this many nodes: 2
# Component 4 has this many nodes: 2
# Component 5 has this many nodes: 2
# Component 6 has this many nodes: 2
# Spanning tree edges in H are = [(0, 5), (0, 3), (0, 4), (0, 2), (1, 2), (4, 6)]
# Adding these edges to G = [(11472, 11457), (17300, 7351), (6292, 17736), (2078, 2006), (24846, 12778), (17313, 28371)]
# Their GEOIDs are = [('021800001001319', '021800001001600'), ('021800001001297', '021800001001605'), ('021800001001187', '021800001001608'), ('021800001001178', '021800001001597'), ('021800001001560', '021800001001598'), ('021800001001609', '021800001001590')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Aleutians West County with geoid = 02016 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 37
# Component 1 has this many nodes: 244
# Component 2 has this many nodes: 217
# Component 3 has this many nodes: 37
# Component 4 has this many nodes: 10
# Component 5 has this many nodes: 7
# Component 6 has this many nodes: 2
# Component 7 has this many nodes: 25
# Component 8 has this many nodes: 13
# Component 9 has this many nodes: 14
# Component 10 has this many nodes: 2
# Component 11 has this many nodes: 3
# Component 12 has this many nodes: 5
# Component 13 has this many nodes: 2
# Component 14 has this many nodes: 3
# Component 15 has this many nodes: 2
# Component 16 has this many nodes: 4
# Component 17 has this many nodes: 3
# Component 18 has this many nodes: 2
# Component 19 has this many nodes: 4
# Component 20 has this many nodes: 2
# Component 21 has this many nodes: 2
# Component 22 has this many nodes: 2
# Component 23 has this many nodes: 2
# Component 24 has this many nodes: 2
# Component 25 has this many nodes: 2
# Component 26 has this many nodes: 2
# Component 27 has this many nodes: 3
# Spanning tree edges in H are = [(0, 6), (1, 17), (1, 23), (1, 24), (1, 26), (1, 11), (2, 4), (2, 20), (3, 25), (3, 8), (4, 27), (5, 6), (5, 22), (7, 13), (7, 10), (8, 20), (9, 21), (9, 18), (9, 22), (10, 19), (11, 12), (12, 27), (13, 16), (14, 19), (15, 19), (16, 18), (19, 26)]
# Adding these edges to G = [(3094, 6195), (13408, 5741), (12958, 11160), (18767, 21428), (3545, 1257), (16147, 15236), (3095, 22758), (819, 13575), (4854, 13877), (14757, 9300), (17039, 3958), (11619, 6195), (6192, 1264), (15689, 18766), (1260, 6362), (23608, 19199), (25769, 7061), (27584, 14937), (11626, 5015), (2649, 27585), (4402, 20243), (24511, 5748), (26233, 14759), (24912, 4847), (357, 27586), (3098, 19631), (27586, 7966)]
# Their GEOIDs are = [('020160001001364', '020160001001427'), ('020160001001177', '020160001001435'), ('020160001001104', '020160001001473'), ('020160001001144', '020160001001438'), ('020160001001187', '020160001001333'), ('020160001001142', '020160001001391'), ('020160001001250', '020160001001307'), ('020160001001242', '020160001001476'), ('020160001001404', '020160001001000'), ('020160001001296', '020160001001345'), ('020160001001309', '020160001001351'), ('020160001001396', '020160001001427'), ('020160001001440', '020160001001315'), ('020160001001275', '020160001001463'), ('020160001001287', '020160001001454'), ('020160001001343', '020160001001475'), ('020160001001328', '020160001001312'), ('020160001001321', '020160001001348'), ('020160001001320', '020160001001314'), ('020160001001455', '020160001001446'), ('020160001001390', '020160001001432'), ('020160001001430', '020160001001352'), ('020160001001464', '020160001001294'), ('020160001001316', '020160001001449'), ('020160001001469', '020160001001448'), ('020160001001295', '020160001001349'), ('020160001001448', '020160001001334')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Kodiak Island County with geoid = 02150 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 848
# Component 1 has this many nodes: 115
# Component 2 has this many nodes: 7
# Component 3 has this many nodes: 5
# Component 4 has this many nodes: 2
# Spanning tree edges in H are = [(0, 2), (0, 1), (0, 4), (3, 4)]
# Adding these edges to G = [(27516, 16733), (5848, 28127), (28126, 13344), (11296, 26161)]
# Their GEOIDs are = [('021500001002084', '021500001002004'), ('021500001001226', '021500001001035'), ('021500001001248', '021500001001349'), ('021500001001295', '021500001001348')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Chugach County with geoid = 02063 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1082
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(15407, 4828)]
# Their GEOIDs are = [('020630003005431', '020630002001316')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Hoonah-Angoon County with geoid = 02105 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 622
# Component 1 has this many nodes: 9
# Component 2 has this many nodes: 9
# Spanning tree edges in H are = [(0, 2), (0, 1)]
# Adding these edges to G = [(2619, 19356), (8773, 17845)]
# Their GEOIDs are = [('021050004002031', '021050004002007'), ('021050004003082', '021050004003007')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Prince of Wales-Hyder County with geoid = 02198 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1631
# Component 1 has this many nodes: 18
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(3669, 24498)]
# Their GEOIDs are = [('021989401003001', '021980003001002')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NV
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state NH
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state VA
#
# The nodes within Montgomery County with geoid = 51121 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1831
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(14186, 142056)]
# Their GEOIDs are = [('511210215013007', '511210215013009')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Bristol County with geoid = 51520 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 610
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(87662, 54422)]
# Their GEOIDs are = [('515200204001013', '515200204001050')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Fairfax County with geoid = 51059 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 8925
# Component 1 has this many nodes: 5
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(52116, 123999)]
# Their GEOIDs are = [('510594406001021', '510594405041004')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Prince William County with geoid = 51153 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 4114
# Component 1 has this many nodes: 5
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(152959, 135432)]
# Their GEOIDs are = [('511539017031008', '511539012323000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Louisa County with geoid = 51109 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 980
# Component 1 has this many nodes: 1
# Component 2 has this many nodes: 1
# Component 3 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1), (0, 3), (0, 2)]
# Adding these edges to G = [(4792, 147740), (150336, 122544), (160537, 91020)]
# Their GEOIDs are = [('511099505002027', '511099505002078'), ('511099505002060', '511099505002080'), ('511099501023026', '511099501023044')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state CO
#
# The nodes within Weld County with geoid = 08123 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 8604
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(42008, 26362)]
# Their GEOIDs are = [('081230020091142', '081230020051049')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Arapahoe County with geoid = 08005 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 7809
# Component 1 has this many nodes: 45
# Component 2 has this many nodes: 35
# Component 3 has this many nodes: 5
# Component 4 has this many nodes: 1
# Component 5 has this many nodes: 1
# Component 6 has this many nodes: 2
# Component 7 has this many nodes: 1
# Spanning tree edges in H are = [(0, 7), (0, 5), (0, 6), (1, 3), (1, 6), (1, 2), (2, 4)]
# Adding these edges to G = [(91739, 61145), (29211, 22253), (138468, 88433), (131704, 64194), (43717, 116716), (136400, 80756), (22245, 81721)]
# Their GEOIDs are = [('080050067122005', '080050067122000'), ('080050872001002', '080050872001000'), ('080050872001004', '080050872001009'), ('080050151001020', '080050151001025'), ('080050151001014', '080050872001008'), ('080050151001003', '080050049511004'), ('080050049511002', '080050049511000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Jefferson County with geoid = 08059 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 8559
# Component 1 has this many nodes: 2
# Component 2 has this many nodes: 1
# Component 3 has this many nodes: 7
# Component 4 has this many nodes: 1
# Component 5 has this many nodes: 1
# Spanning tree edges in H are = [(0, 2), (0, 5), (0, 1), (1, 3), (2, 4)]
# Adding these edges to G = [(35107, 4892), (8380, 40670), (135562, 33892), (126934, 72047), (4892, 137609)]
# Their GEOIDs are = [('080590119042002', '080590119042020'), ('080590119042016', '080590119042018'), ('080590120502018', '080590120502030'), ('080590120502031', '080590120502006'), ('080590119042020', '080590119042019')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Boulder County with geoid = 08013 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 6019
# Component 1 has this many nodes: 4
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(129764, 41525)]
# Their GEOIDs are = [('080130608013015', '080130608011002')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Denver County with geoid = 08031 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 10147
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(74364, 131206)]
# Their GEOIDs are = [('080310153002012', '080310155002000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Broomfield County with geoid = 08014 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1167
# Component 1 has this many nodes: 3
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(111689, 83181)]
# Their GEOIDs are = [('080149803001000', '080149801001000')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state CA
#
# The nodes within Santa Barbara County with geoid = 06083 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 7211
# Component 1 has this many nodes: 44
# Component 2 has this many nodes: 3
# Spanning tree edges in H are = [(0, 1), (1, 2)]
# Adding these edges to G = [(267058, 181392), (27616, 55751)]
# Their GEOIDs are = [('060839900000016', '060839900000033'), ('060839801001007', '060839900000034')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Ventura County with geoid = 06111 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 10466
# Component 1 has this many nodes: 7
# Component 2 has this many nodes: 6
# Spanning tree edges in H are = [(0, 2), (1, 2)]
# Adding these edges to G = [(418821, 186501), (427671, 45435)]
# Their GEOIDs are = [('061119901000008', '061119901000013'), ('061119800001000', '061110036181000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Los Angeles County with geoid = 06037 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 91520
# Component 1 has this many nodes: 25
# Component 2 has this many nodes: 81
# Spanning tree edges in H are = [(0, 2), (1, 2)]
# Adding these edges to G = [(251242, 218910), (463004, 73035)]
# Their GEOIDs are = [('060379903000009', '060375991002000'), ('060375991001017', '060375991002006')]
# After adding these edges, is G_county now connected? True
#
# The nodes within San Francisco County with geoid = 06075 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 5983
# Component 1 has this many nodes: 3
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(55358, 241946)]
# Their GEOIDs are = [('060759901000001', '060759804011002')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state AL
#
# The nodes within Jackson County with geoid = 01071 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 3181
# Component 1 has this many nodes: 5
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(76130, 183386)]
# Their GEOIDs are = [('010719507003068', '010719507003084')]
# After adding these edges, is G_county now connected? True
# Graph is connected; no need for more inter-county edges.
#
# Beginning state AR
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state VT
#
# The nodes within Caledonia County with geoid = 50005 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1891
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(14996, 12512)]
# Their GEOIDs are = [('500059578003074', '500059578003103')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state IL
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state GA
#
# The nodes within Lee County with geoid = 13177 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 598
# Component 1 has this many nodes: 3
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(41946, 227629)]
# Their GEOIDs are = [('131770203021053', '131770203021061')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Upson County with geoid = 13293 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 1106
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(36268, 211989)]
# Their GEOIDs are = [('132930102021004', '132930102021000')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Brooks County with geoid = 13027 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 982
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(144936, 231189)]
# Their GEOIDs are = [('130279606001050', '130279606001054')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Taylor County with geoid = 13269 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 782
# Component 1 has this many nodes: 4
# Component 2 has this many nodes: 1
# Spanning tree edges in H are = [(0, 2), (0, 1)]
# Adding these edges to G = [(83937, 141013), (156972, 58140)]
# Their GEOIDs are = [('132699503012115', '132699503012161'), ('132699502001078', '132699502001101')]
# After adding these edges, is G_county now connected? True
#
# The nodes within Macon County with geoid = 13193 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 945
# Component 1 has this many nodes: 2
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(82524, 168231)]
# Their GEOIDs are = [('131930002001025', '131930002001001')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state IN
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state IA
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MA
#
# The nodes within Norfolk County with geoid = 25021 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 8990
# Component 1 has this many nodes: 553
# Component 2 has this many nodes: 139
# Spanning tree edges in H are = [(0, 1), (0, 2)]
# Adding these edges to G = [(353, 26996), (5093, 1879)]
# Their GEOIDs are = [('250214021011000', '250214012011017'), ('250214228001001', '250214231023006')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state AZ
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state ID
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state CT
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state ME
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MD
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state OK
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state OH
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state UT
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MO
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MN
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MI
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state RI
#
# The nodes within Washington County with geoid = 44009 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 4277
# Component 1 has this many nodes: 64
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(12934, 941)]
# Their GEOIDs are = [('440099901000017', '440099902000001')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state KS
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MT
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state MS
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state SC
#
# The nodes within Pickens County with geoid = 45077 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 3506
# Component 1 has this many nodes: 1
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(74578, 92915)]
# Their GEOIDs are = [('450770112022055', '450770112022061')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state KY
#
# The nodes within Fulton County with geoid = 21075 are not connected!
# Adding intra-county edges...
# Component 0 has this many nodes: 617
# Component 1 has this many nodes: 5
# Spanning tree edges in H are = [(0, 1)]
# Adding these edges to G = [(65394, 28010)]
# Their GEOIDs are = [('210759602004106', '210759602004104')]
# After adding these edges, is G_county now connected? True
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state OR
#
# Graph is connected; no need for more inter-county edges.
#
# Beginning state SD
#
# Graph is connected; no need for more inter-county edges.
