# %%
import networkx as nx
from gerrychain import Graph
import math
import gurobipy as gp
from gurobipy import GRB

#import matplotlib.pyplot as plt
from util import update_attributes, get_k_L_U
from sketch import sketch
from detail import detail
from clusterings import clusterings

filepath1 = 'C:\\districting-data-2020\\'
filepath2 = 'C:\\districting-data-2020-conn\\'

# %%
# calculated in enacted_splits.ipynb
enacted_splits = {('AK', 'CD'): 0, ('AL', 'CD'): 6, ('AR', 'CD'): 3, ('AZ', 'CD'): 15, ('CA', 'CD'): 72, ('CO', 'CD'): 20, ('CT', 'CD'): 10, ('DE', 'CD'): 0, ('FL', 'CD'): 31, ('GA', 'CD'): 21, ('HI', 'CD'): 1, ('IA', 'CD'): 0, ('ID', 'CD'): 1, ('IL', 'CD'): 53, ('IN', 'CD'): 8, ('KS', 'CD'): 4, ('KY', 'CD'): 6, ('LA', 'CD'): 15, ('MA', 'CD'): 22, ('MD', 'CD'): 9, ('ME', 'CD'): 1, ('MI', 'CD'): 21, ('MN', 'CD'): 12, ('MO', 'CD'): 10, ('MS', 'CD'): 4, ('MT', 'CD'): 1, ('NC', 'CD'): 13, ('ND', 'CD'): 0, ('NE', 'CD'): 2, ('NH', 'CD'): 5, ('NJ', 'CD'): 20, ('NM', 'CD'): 10, ('NV', 'CD'): 5, ('NY', 'CD'): 26, ('OH', 'CD'): 14, ('OK', 'CD'): 7, ('OR', 'CD'): 16, ('PA', 'CD'): 17, ('RI', 'CD'): 1, ('SC', 'CD'): 10, ('SD', 'CD'): 0, ('TN', 'CD'): 11, ('TX', 'CD'): 59, ('UT', 'CD'): 7, ('VA', 'CD'): 11, ('VT', 'CD'): 0, ('WA', 'CD'): 11, ('WI', 'CD'): 13, ('WV', 'CD'): 0, ('WY', 'CD'): 0, ('AK', 'SS'): 19, ('AL', 'SS'): 35, ('AR', 'SS'): 51, ('AZ', 'SS'): 44, ('CA', 'SS'): 56, ('CO', 'SS'): 42, ('CT', 'SS'): 49, ('DE', 'SS'): 20, ('FL', 'SS'): 32, ('GA', 'SS'): 60, ('HI', 'SS'): 21, ('IA', 'SS'): 46, ('ID', 'SS'): 25, ('IL', 'SS'): 135, ('IN', 'SS'): 48, ('KS', 'SS'): 36, ('KY', 'SS'): 21, ('LA', 'SS'): 77, ('MA', 'SS'): 59, ('MD', 'SS'): 45, ('ME', 'SS'): 40, ('MI', 'SS'): 64, ('MN', 'SS'): 100, ('MO', 'SS'): 16, ('MS', 'SS'): 64, ('MT', 'SS'): 56, ('NC', 'SS'): 24, ('ND', 'SS'): 49, ('NE', 'SS'): 37, ('NH', 'SS'): 40, ('NJ', 'SS'): 56, ('NM', 'SS'): 64, ('NV', 'SS'): 21, ('NY', 'SS'): 66, ('OH', 'SS'): 20, ('OK', 'SS'): 59, ('OR', 'SS'): 47, ('PA', 'SS'): 47, ('RI', 'SS'): 41, ('SC', 'SS'): 68, ('SD', 'SS'): 29, ('TN', 'SS'): 15, ('TX', 'SS'): 41, ('UT', 'SS'): 41, ('VA', 'SS'): 34, ('VT', 'SS'): 18, ('WA', 'SS'): 59, ('WI', 'SS'): 73, ('WV', 'SS'): 13, ('WY', 'SS'): 25, ('AK', 'SH'): 39, ('AL', 'SH'): 115, ('AR', 'SH'): 128, ('AZ', 'SH'): 44, ('CA', 'SH'): 95, ('CO', 'SH'): 73, ('CT', 'SH'): 162, ('DE', 'SH'): 40, ('FL', 'SH'): 112, ('GA', 'SH'): 209, ('HI', 'SH'): 47, ('IA', 'SH'): 92, ('ID', 'SH'): 25, ('IL', 'SH'): 220, ('IN', 'SH'): 129, ('KS', 'SH'): 127, ('KY', 'SH'): 80, ('LA', 'SH'): 116, ('MA', 'SH'): 182, ('MD', 'SH'): 67, ('ME', 'SH'): 166, ('MI', 'SH'): 154, ('MN', 'SH'): 176, ('MO', 'SH'): 137, ('MS', 'SH'): 181, ('MT', 'SH'): 99, ('NC', 'SH'): 80, ('ND', 'SH'): 53, ('NH', 'SH'): 154, ('NJ', 'SH'): 56, ('NM', 'SH'): 86, ('NV', 'SH'): 43, ('NY', 'SH'): 179, ('OH', 'SH'): 77, ('OK', 'SH'): 134, ('OR', 'SH'): 79, ('PA', 'SH'): 186, ('RI', 'SH'): 75, ('SC', 'SH'): 145, ('SD', 'SH'): 31, ('TN', 'SH'): 74, ('TX', 'SH'): 101, ('UT', 'SH'): 72, ('VA', 'SH'): 98, ('VT', 'SH'): 118, ('WA', 'SH'): 59, ('WI', 'SH'): 159, ('WV', 'SH'): 89, ('WY', 'SH'): 56}

# %%
def number_of_county_splits(districts_geoid):
    county_geoids = { geoid[0:5] for district in districts_geoid for geoid in district }
    county_assignment = { county_geoid : list() for county_geoid in county_geoids }
    for j in range(len(districts_geoid)):
        for geoid in districts_geoid[j]:
            county_geoid = geoid[0:5]
            if j not in county_assignment[county_geoid]:
                county_assignment[county_geoid].append(j)
    return sum( len(county_assignment[cg]) - 1 for cg in county_assignment.keys() )

# %%
import csv

def export_to_baf(geoid_assignment, outfilename):
    
    with open(outfilename, 'w') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        for i in GB.nodes:
            geoid = GB.nodes[i]['GEOID20']
            county = geoid[0:5]
            tract = geoid[0:11]
            block = geoid
            if county in geoid_assignment:
                row = [geoid, geoid_assignment[county]+1]
            elif tract in geoid_assignment:
                row = [geoid, geoid_assignment[tract]+1]
            else:
                row = [geoid, geoid_assignment[block]+1]
            csvwriter.writerow(row) 
    
    return

# %%
from number_of_districts import congressional_districts_2020
states = sorted([ state for state in congressional_districts_2020.keys() ])

results = dict()
instances = list( clusterings.keys() )
instances.reverse()

for (state, district_type) in {('WY','SS'),('WY','SH')}: 

    print("**********************************")
    print("State:",state,"district_type:",district_type)
    print("**********************************")

    # get county graph
    filename = state + '_county.json'
    GC = Graph.from_json( filepath1 + filename )
    update_attributes(GC, state)    

    # get tract graph
    filename = state + '_tract.json'
    GT = Graph.from_json( filepath2 + filename )
    update_attributes(GT, state)    

    # get block graph
    filename = state + '_block.json'
    GB = Graph.from_json( filepath2 + filename )
    update_attributes(GB, state)    

    # get values of k, L, U; check connectivity
    (k, L, U) = get_k_L_U(GC, state, district_type)
    if k <= 1 or not nx.is_connected(GC) or not nx.is_connected(GT) or not nx.is_connected(GB):
        print("Skipping this state because k <= 1 or because graph is disconnected.")
        continue

    clusters = clusterings[state,district_type]['clusters'] 
    sizes = clusterings[state,district_type]['sizes'] 
    districts = list()

    for p in range(len(clusters)):

        cluster = clusters[p]
        size = sizes[p]
        GS = GC.subgraph(cluster)
        
        print("size =",size)
        print("cluster =",cluster)
        print("population = ",[ GS.nodes[i]['TOTPOP'] for i in GS.nodes ] )
        print("L,U =",L,U)

        ################################
        # get a sketch for this cluster
        ################################
        
        (xsoln, ysoln, zsoln) = sketch(GS, L, U, size)
        if xsoln is None:
            print("Sketch indicates that this cluster is infeasible; impossible to get k-1 splits!!!")
            districts = None
            break

        ################################
        # visualize this cluster
        ################################
        
#         node_pos = { i : ( GS.nodes[i]['X'], GS.nodes[i]['Y'] ) for i in GS.nodes }
#         node_colors = [ list(xsoln[i])[0] for i in GS.nodes ]
#         edge_colors = [ list(ysoln[u,v])[0] if len(ysoln[u,v]) > 0 else -1 for u,v in GS.edges ]

#         title = state + '_' + district_type
#         plt.figure(title)
#         my_labels = { i : list(xsoln[i].keys()) for i in GS.nodes }
#         nx.draw(GS, pos=node_pos, node_color=node_colors, edge_color=edge_colors, with_labels=True, labels=my_labels, font_color="red")
#         plt.show()

        #########################
        # detail this cluster
        #########################
        
        # first, try tract-level
        sketch_support = { GS.nodes[i]['GEOID20'] : list(xsoln[i].keys()) for i in GS.nodes }
        tracts = [ i for i in GT.nodes if GT.nodes[i]['GEOID20'][0:5] in sketch_support.keys() ]
        cluster_districts = detail(GT.subgraph(tracts), L, U, size, sketch_support)
        cluster_districts_geoid = None # just the initial value!

        if cluster_districts is not None:
            cluster_districts_geoid = [ [ GT.nodes[i]['GEOID20'] for i in district ] for district in cluster_districts ]
        else:
            # second, try block-level
            blocks = [ i for i in GB.nodes if GB.nodes[i]['GEOID20'][0:5] in sketch_support.keys() ]
            cluster_districts = detail(GB.subgraph(blocks), L, U, size, sketch_support)
            if cluster_districts is not None:
                cluster_districts_geoid = [ [ GB.nodes[i]['GEOID20'] for i in district ] for district in cluster_districts ]

        # both tries unsuccessful?
        if cluster_districts_geoid is None:
            districts = None
            break
        else:
            districts += cluster_districts_geoid

    # all clusters successful?
    if districts is not None:
        assert k == len(districts)
        splits = number_of_county_splits(districts)
    else:
        districts_geoid = None
        splits = None

    # store results
    results[state,district_type] = dict()
    results[state,district_type]['clusters'] = clusters
    results[state,district_type]['num_clusters'] = len(sizes)
    results[state,district_type]['sizes'] = sizes
    results[state,district_type]['districts'] = districts
    results[state,district_type]['counties'] = GC.number_of_nodes()
    results[state,district_type]['k'] = k
    results[state,district_type]['L'] = f'{L:,d}'
    results[state,district_type]['U'] = f'{U:,d}'
    results[state,district_type]['obvious_LB'] = sum( math.ceil( GC.nodes[i]['TOTPOP'] / U ) - 1 for i in GC.nodes )
    results[state,district_type]['splits_LB'] = k - len(sizes)
    results[state,district_type]['splits_UB'] = splits
    
    # export districts to block assignment file
    if districts is not None:
        geoid_assignment = { g : j for j in range(len(districts)) for g in districts[j] }
        outfilename = "min_county_splits_" + state + '_' + district_type + "_(by_Maral_Shahmizad_and_Austin_Buchanan_of_Oklahoma_State_University).baf"
        export_to_baf(geoid_assignment, outfilename)
# Out:
# **********************************
# State: WY district_type: SH
# **********************************
# Starting WY with k = 62 and deviation = 0.1
# Thus, we have L = 8839 and U = 9769
# size = 11
# cluster = [1]
# population =  [100512]
# L,U = 8839 9769
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-27
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 10897320.42 	 0.00
# 2 	 7529593.02 	 0.00
# 3 	 6027280.26 	 0.00
# 4 	 5900708.36 	 0.00
# 5 	 5900332.97 	 0.00
# 6 	 5900324.48 	 0.00
# 7 	 5900324.48 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [142, 37, 71, 34, 84, 139, 143, 82, 31, 83, 135]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 335 rows, 297 columns and 1969 nonzeros
# Model fingerprint: 0xe1e123e1
# Variable types: 0 continuous, 297 integer (297 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [6e+01, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 216 rows and 184 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 49 rows, 297 columns and 891 nonzeros
# Model fingerprint: 0x39859dd5
# Variable types: 0 continuous, 297 integer (297 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [6e+01, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve time: 0.00s
# Presolved: 49 rows, 297 columns, 891 nonzeros
# Variable types: 0 continuous, 297 integer (297 binary)
#
# Root relaxation: objective 5.996061e+06, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5996060.88    0   16          - 5996060.88      -     -    0s
#      0     0 1.1533e+07    0   21          - 1.1533e+07      -     -    0s
#      0     0 1.1863e+07    0   26          - 1.1863e+07      -     -    0s
#      0     0 1.1893e+07    0   26          - 1.1893e+07      -     -    0s
#      0     0 1.1903e+07    0   22          - 1.1903e+07      -     -    0s
#      0     0 1.1985e+07    0   42          - 1.1985e+07      -     -    0s
#      0     0 1.1988e+07    0   35          - 1.1988e+07      -     -    0s
#      0     0 1.2052e+07    0   35          - 1.2052e+07      -     -    0s
#      0     0 1.2077e+07    0   35          - 1.2077e+07      -     -    0s
#      0     0 1.2080e+07    0   36          - 1.2080e+07      -     -    0s
#      0     0 1.2137e+07    0   39          - 1.2137e+07      -     -    0s
#      0     0 1.2170e+07    0   38          - 1.2170e+07      -     -    0s
#      0     0 1.2176e+07    0   38          - 1.2176e+07      -     -    0s
#      0     0 1.2177e+07    0   38          - 1.2177e+07      -     -    0s
#      0     0 1.2323e+07    0   38          - 1.2323e+07      -     -    0s
#      0     0 1.2346e+07    0   46          - 1.2346e+07      -     -    0s
#      0     0 1.2415e+07    0   42          - 1.2415e+07      -     -    0s
#      0     0 1.2429e+07    0   45          - 1.2429e+07      -     -    0s
#      0     0 1.2429e+07    0   44          - 1.2429e+07      -     -    0s
#      0     0 1.2849e+07    0   30          - 1.2849e+07      -     -    0s
#      0     0 1.2934e+07    0   40          - 1.2934e+07      -     -    0s
#      0     0 1.2937e+07    0   43          - 1.2937e+07      -     -    0s
#      0     0 1.3106e+07    0   37          - 1.3106e+07      -     -    0s
#      0     0 1.3217e+07    0   43          - 1.3217e+07      -     -    0s
#      0     0 1.3229e+07    0   42          - 1.3229e+07      -     -    0s
#      0     0 1.3252e+07    0   43          - 1.3252e+07      -     -    0s
#      0     0 1.3252e+07    0   44          - 1.3252e+07      -     -    0s
#      0     0 1.3762e+07    0   41          - 1.3762e+07      -     -    0s
#      0     0 1.4561e+07    0   37          - 1.4561e+07      -     -    0s
#      0     0 1.4584e+07    0   46          - 1.4584e+07      -     -    0s
#      0     0 1.4589e+07    0   45          - 1.4589e+07      -     -    0s
#      0     0 1.4976e+07    0   47          - 1.4976e+07      -     -    0s
#      0     0 1.5517e+07    0   59          - 1.5517e+07      -     -    0s
#      0     0 1.5561e+07    0   55          - 1.5561e+07      -     -    0s
#      0     0 1.5617e+07    0   58          - 1.5617e+07      -     -    0s
#      0     0 1.5621e+07    0   60          - 1.5621e+07      -     -    0s
#      0     0 1.6421e+07    0   54          - 1.6421e+07      -     -    0s
#      0     0 1.7891e+07    0   47          - 1.7891e+07      -     -    0s
#      0     0 1.7968e+07    0   56          - 1.7968e+07      -     -    0s
#      0     0 1.7984e+07    0   55          - 1.7984e+07      -     -    0s
#      0     0 1.7984e+07    0   56          - 1.7984e+07      -     -    0s
#      0     0 1.8256e+07    0   41          - 1.8256e+07      -     -    0s
#      0     0 1.8360e+07    0   56          - 1.8360e+07      -     -    0s
#      0     0 1.8711e+07    0   56          - 1.8711e+07      -     -    0s
#      0     0 1.8819e+07    0   55          - 1.8819e+07      -     -    0s
#      0     0 1.9274e+07    0   64          - 1.9274e+07      -     -    0s
#      0     0 1.9279e+07    0   59          - 1.9279e+07      -     -    0s
#      0     0 1.9850e+07    0   63          - 1.9850e+07      -     -    0s
#      0     0 2.4935e+07    0   60          - 2.4935e+07      -     -    0s
#      0     0 2.5238e+07    0   58          - 2.5238e+07      -     -    0s
#      0     0 2.5416e+07    0   56          - 2.5416e+07      -     -    0s
#      0     0 2.5418e+07    0   60          - 2.5418e+07      -     -    0s
#      0     0 2.6669e+07    0   63          - 2.6669e+07      -     -    0s
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Cutting planes:
#   Cover: 21
#   MIR: 38
#   StrongCG: 14
#
# Explored 1 nodes (1906 simplex iterations) in 0.21 seconds (0.06 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 431, time in user-callback 0.00 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.16
# 1 	 15255840.29 	 0.10
# 2 	 6484789.29 	 0.03
# 3 	 5614302.69 	 0.03
# 4 	 5600521.20 	 0.03
# 5 	 5595849.27 	 0.02
# 6 	 5594664.46 	 0.02
# 7 	 5594038.21 	 0.02
# 8 	 5593635.47 	 0.02
# 9 	 5592854.03 	 0.02
# 10 	 5591823.86 	 0.02
# 11 	 5590809.56 	 0.02
# 12 	 5589998.03 	 0.02
# 13 	 5588631.46 	 0.02
# 14 	 5585523.21 	 0.02
# 15 	 5581570.19 	 0.02
# 16 	 5576253.20 	 0.02
# 17 	 5574180.20 	 0.02
# 18 	 5573703.13 	 0.02
# 19 	 5573636.55 	 0.02
# 20 	 5573619.70 	 0.02
# 21 	 5573614.31 	 0.01
# 22 	 5573613.80 	 0.01
# 23 	 5573611.49 	 0.01
# 24 	 5573610.96 	 0.01
# 25 	 5573610.96 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [46472, 1495, 22577, 33563, 37300, 7474, 12486, 35188, 48381, 4675, 6126]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 47723 rows, 43736 columns and 250811 nonzeros
# Model fingerprint: 0x64bee54e
# Variable types: 0 continuous, 43736 integer (43736 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [2e-02, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2274 rows and 2123 columns
# Presolve time: 1.79s
# Presolved: 45449 rows, 41613 columns, 228605 nonzeros
# Variable types: 0 continuous, 41613 integer (41613 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 5.580254e+06, 7896 iterations, 0.72 seconds (0.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5580253.58    0   87          - 5580253.58      -     -    3s
# H    0     0                    5582734.1764 5580253.58  0.04%     -    4s
#
# Explored 1 nodes (17709 simplex iterations) in 4.10 seconds (1.91 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 5.58273e+06
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.582734176436e+06, best bound 5.580253575432e+06, gap 0.0444%
# size = 9
# cluster = [0]
# population =  [79955]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 12287852.49 	 0.00
# 2 	 8860160.06 	 0.00
# 3 	 8800549.54 	 0.00
# 4 	 8792413.01 	 0.00
# 5 	 8791729.33 	 0.00
# 6 	 8791729.33 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [126, 117, 157, 98, 18, 118, 102, 123, 99]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 209 rows, 180 columns and 1188 nonzeros
# Model fingerprint: 0x833db337
# Variable types: 0 continuous, 180 integer (180 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 52 rows and 120 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 38 rows, 180 columns and 540 nonzeros
# Model fingerprint: 0xfa210b17
# Variable types: 0 continuous, 180 integer (180 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve time: 0.00s
# Presolved: 38 rows, 180 columns, 540 nonzeros
# Variable types: 0 continuous, 180 integer (180 binary)
#
# Root relaxation: infeasible, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (32 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 134, time in user-callback 0.00 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.15
# 1 	 6551571.20 	 0.09
# 2 	 4110917.81 	 0.05
# 3 	 4028320.76 	 0.02
# 4 	 4003378.54 	 0.02
# 5 	 3985759.21 	 0.03
# 6 	 3975428.87 	 0.02
# 7 	 3971799.77 	 0.02
# 8 	 3968860.29 	 0.02
# 9 	 3967576.33 	 0.02
# 10 	 3966759.65 	 0.02
# 11 	 3966023.81 	 0.02
# 12 	 3965575.32 	 0.02
# 13 	 3965325.02 	 0.02
# 14 	 3965225.58 	 0.02
# 15 	 3965197.00 	 0.02
# 16 	 3965184.08 	 0.02
# 17 	 3965172.77 	 0.01
# 18 	 3965156.90 	 0.02
# 19 	 3965150.98 	 0.02
# 20 	 3965150.96 	 0.01
# 21 	 3965150.96 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [40887, 14761, 1204, 20526, 40027, 24425, 2892, 39936, 34928]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 48859 rows, 43965 columns and 246105 nonzeros
# Model fingerprint: 0x601c037e
# Variable types: 0 continuous, 43965 integer (43965 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [7e-03, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 1218 rows and 1164 columns
# Presolve time: 1.89s
# Presolved: 47641 rows, 42801 columns, 229837 nonzeros
# Variable types: 0 continuous, 42801 integer (42801 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    27965    5.1348327e+06   5.927904e+01   4.854482e+09      5s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    21378    3.9670423e+06   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 3.967042e+06, 21378 iterations, 3.64 seconds (1.93 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3967042.34    0  648          - 3967042.34      -     -    8s
#      0     0 3967485.55    0  566          - 3967485.55      -     -   12s
#      0     0 3967485.55    0  568          - 3967485.55      -     -   12s
#      0     0 3967489.22    0  371          - 3967489.22      -     -   15s
#      0     0 3967489.22    0  336          - 3967489.22      -     -   15s
#      0     0 3967489.22    0  225          - 3967489.22      -     -   21s
#      0     0 3967489.22    0  225          - 3967489.22      -     -   21s
#      0     0 3967513.66    0  262          - 3967513.66      -     -   28s
#      0     0 3967513.66    0  252          - 3967513.66      -     -   28s
# H    0     0                    3968389.4854 3967513.66  0.02%     -   30s
#
# Cutting planes:
#   Gomory: 28
#   Lift-and-project: 2
#   Implied bound: 5
#   Clique: 626
#   MIR: 84
#   StrongCG: 2
#   GUB cover: 2
#   Zero half: 61
#   RLT: 60
#
# Explored 1 nodes (70026 simplex iterations) in 30.66 seconds (13.71 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 3.96839e+06
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.968389485381e+06, best bound 3.967513658830e+06, gap 0.0221%
# size = 10
# cluster = [5, 9, 13, 16]
# population =  [4621, 23331, 39234, 29624]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 130721682.21 	 0.00
# 2 	 124195932.17 	 0.00
# 3 	 121213611.74 	 0.00
# 4 	 121213611.74 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [42, 59, 61, 39, 54, 89, 144, 138, 91, 2]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 318 rows, 280 columns and 1700 nonzeros
# Model fingerprint: 0xdc1a2f70
# Variable types: 169 continuous, 111 integer (111 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [4e+03, 3e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 210 rows and 239 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 48 rows, 280 columns and 840 nonzeros
# Model fingerprint: 0x25a48d79
# Variable types: 169 continuous, 111 integer (111 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [4e+03, 3e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 4 rows and 185 columns
# Presolve time: 0.00s
# Presolved: 44 rows, 95 columns, 287 nonzeros
# Variable types: 0 continuous, 95 integer (95 binary)
#
# Root relaxation: infeasible, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (46 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 297, time in user-callback 0.01 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.14
# 1 	 133658473.24 	 0.06
# 2 	 109173370.61 	 0.04
# 3 	 109045970.58 	 0.02
# 4 	 109005456.73 	 0.03
# 5 	 108962915.46 	 0.03
# 6 	 108870627.41 	 0.02
# 7 	 108839586.35 	 0.02
# 8 	 108828968.89 	 0.02
# 9 	 108828482.43 	 0.02
# 10 	 108828461.66 	 0.03
# 11 	 108828460.84 	 0.02
# 12 	 108828456.67 	 0.02
# 13 	 108828385.15 	 0.02
# 14 	 108828381.66 	 0.02
# 15 	 108828381.66 	 0.02
# 16 	 108828381.66 	 0.02
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [15003, 27510, 31718, 12515, 20076, 35987, 9117, 29875, 48785, 6427]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 98075 rows, 89150 columns and 476620 nonzeros
# Model fingerprint: 0xdc516eaf
# Variable types: 52718 continuous, 36432 integer (36432 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [1e-01, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 59921 rows and 58115 columns
# Presolve time: 4.07s
# Presolved: 38154 rows, 31035 columns, 159394 nonzeros
# Variable types: 0 continuous, 31035 integer (31035 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    23661    1.0600516e+08   2.100905e+02   1.973022e+09      5s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    14252    1.0895546e+08   0.000000e+00   0.000000e+00      6s
#
# Root relaxation: objective 1.089555e+08, 14252 iterations, 1.43 seconds (0.72 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.0896e+08    0 1387          - 1.0896e+08      -     -    7s
#      0     0 1.0896e+08    0 1659          - 1.0896e+08      -     -    9s
#      0     0 1.0896e+08    0 1199          - 1.0896e+08      -     -    9s
#      0     0 1.0896e+08    0 1118          - 1.0896e+08      -     -   10s
#      0     0 1.0896e+08    0 1128          - 1.0896e+08      -     -   10s
#      0     0 1.0896e+08    0 1211          - 1.0896e+08      -     -   11s
#      0     0 1.0896e+08    0 1373          - 1.0896e+08      -     -   12s
#      0     0 1.0896e+08    0 1164          - 1.0896e+08      -     -   12s
#      0     0 1.0896e+08    0 1194          - 1.0896e+08      -     -   14s
#      0     0 1.0896e+08    0 1226          - 1.0896e+08      -     -   14s
# H    0     0                    1.091059e+08 1.0896e+08  0.13%     -   15s
#
# Cutting planes:
#   Gomory: 10
#   Lift-and-project: 2
#   Cover: 4
#   Implied bound: 8
#   Clique: 990
#   MIR: 180
#   StrongCG: 5
#   GUB cover: 7
#   Zero half: 183
#   RLT: 117
#
# Explored 1 nodes (40834 simplex iterations) in 16.61 seconds (6.49 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 1.09106e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.091058572050e+08, best bound 1.089597897995e+08, gap 0.1339%
# size = 6
# cluster = [6, 7, 15, 17]
# population =  [7685, 11521, 8447, 30921]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 42393018.19 	 0.00
# 2 	 40784576.16 	 0.00
# 3 	 40749730.12 	 0.00
# 4 	 40617355.95 	 0.00
# 5 	 40615973.29 	 0.00
# 6 	 40615973.29 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [65, 63, 66, 19, 27, 125]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 118 rows, 96 columns and 570 nonzeros
# Model fingerprint: 0x1409af73
# Variable types: 53 continuous, 43 integer (43 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [2e+03, 7e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 81 rows and 82 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 28 rows, 96 columns and 288 nonzeros
# Model fingerprint: 0xbf2470a6
# Variable types: 53 continuous, 43 integer (43 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [2e+03, 7e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 3 rows and 62 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 45, time in user-callback 0.00 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.07
# 1 	 45518602.04 	 0.02
# 2 	 43689132.73 	 0.01
# 3 	 43686168.74 	 0.01
# 4 	 43685631.19 	 0.01
# 5 	 43685517.57 	 0.01
# 6 	 43685377.96 	 0.01
# 7 	 43685149.00 	 0.01
# 8 	 43684816.23 	 0.01
# 9 	 43684228.07 	 0.01
# 10 	 43683979.15 	 0.01
# 11 	 43683955.02 	 0.01
# 12 	 43683952.51 	 0.01
# 13 	 43683952.51 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [5020, 18487, 12676, 44483, 25630, 45183]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 49475 rows, 42402 columns and 229146 nonzeros
# Model fingerprint: 0xb5cfeabc
# Variable types: 25213 continuous, 17189 integer (17189 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [5e-02, 6e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 36810 rows and 33128 columns
# Presolve time: 1.27s
# Presolved: 12665 rows, 9274 columns, 51146 nonzeros
# Variable types: 0 continuous, 9274 integer (9269 binary)
#
# Root relaxation: objective 4.456316e+07, 4392 iterations, 0.10 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.4563e+07    0  203          - 4.4563e+07      -     -    1s
#      0     0 4.4590e+07    0  226          - 4.4590e+07      -     -    2s
#      0     0 4.4590e+07    0  229          - 4.4590e+07      -     -    2s
#      0     0 4.4594e+07    0  205          - 4.4594e+07      -     -    2s
#      0     0 4.4594e+07    0  207          - 4.4594e+07      -     -    2s
#      0     0 4.4594e+07    0  229          - 4.4594e+07      -     -    3s
#      0     0 4.4594e+07    0  245          - 4.4594e+07      -     -    3s
#      0     0 4.4594e+07    0  247          - 4.4594e+07      -     -    3s
#      0     0 4.4595e+07    0  178          - 4.4595e+07      -     -    4s
# H    0     0                    4.475003e+07 4.4595e+07  0.35%     -    4s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 3
#   Implied bound: 10
#   Clique: 173
#   MIR: 42
#   StrongCG: 1
#   Zero half: 22
#   RLT: 37
#   PSD: 1
#
# Explored 1 nodes (7459 simplex iterations) in 4.67 seconds (1.95 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 4.475e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.475003450155e+07, best bound 4.459464165368e+07, gap 0.3472%
# size = 4
# cluster = [4]
# population =  [37066]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 2649023.79 	 0.00
# 2 	 2521666.98 	 0.00
# 3 	 2520325.56 	 0.00
# 4 	 2520325.56 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [107, 29, 109, 114]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 59 rows, 44 columns and 268 nonzeros
# Model fingerprint: 0x5074b160
# Variable types: 0 continuous, 44 integer (44 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [8e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 48 rows and 38 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 19 rows, 44 columns and 132 nonzeros
# Model fingerprint: 0x4a7b2152
# Variable types: 0 continuous, 44 integer (44 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [8e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve time: 0.00s
# Presolved: 19 rows, 44 columns, 132 nonzeros
# Variable types: 0 continuous, 44 integer (44 binary)
#
# Root relaxation: objective 2.537364e+06, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2537363.68    0    6          - 2537363.68      -     -    0s
#      0     0 2592991.11    0   20          - 2592991.11      -     -    0s
#      0     0 2623658.80    0   12          - 2623658.80      -     -    0s
#      0     0 2623678.89    0   12          - 2623678.89      -     -    0s
#      0     0 2778586.40    0   16          - 2778586.40      -     -    0s
#      0     0 2825209.08    0   15          - 2825209.08      -     -    0s
#      0     0 2834338.84    0   18          - 2834338.84      -     -    0s
#      0     0 2837882.95    0   18          - 2837882.95      -     -    0s
#      0     0 2862831.74    0   23          - 2862831.74      -     -    0s
#      0     0 2872243.46    0   24          - 2872243.46      -     -    0s
#      0     0 2877166.11    0   27          - 2877166.11      -     -    0s
#      0     0 2880684.75    0   27          - 2880684.75      -     -    0s
#      0     0 2880684.75    0   27          - 2880684.75      -     -    0s
#      0     2 2908863.42    0   27          - 2908863.42      -     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   MIR: 12
#   StrongCG: 1
#   Lazy constraints: 48
#
# Explored 1083 nodes (4799 simplex iterations) in 0.14 seconds (0.02 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 2434, time in user-callback 0.02 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.02
# 1 	 4533637.50 	 0.01
# 2 	 3806224.76 	 0.01
# 3 	 3798761.38 	 0.01
# 4 	 3797249.56 	 0.00
# 5 	 3797232.75 	 0.01
# 6 	 3797232.00 	 0.01
# 7 	 3797231.99 	 0.01
# 8 	 3797231.99 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [51416, 36833, 27446, 8280]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 15534 rows, 12424 columns and 65592 nonzeros
# Model fingerprint: 0x8c70fb1e
# Variable types: 0 continuous, 12424 integer (12424 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [7e-02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 2239 rows and 1801 columns
# Presolve time: 0.77s
# Presolved: 13295 rows, 10623 columns, 54641 nonzeros
# Variable types: 0 continuous, 10623 integer (10623 binary)
#
# Root relaxation: objective 3.797668e+06, 7117 iterations, 0.17 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3797668.16    0  593          - 3797668.16      -     -    1s
#      0     0 3797721.85    0  720          - 3797721.85      -     -    2s
#      0     0 3797721.85    0  724          - 3797721.85      -     -    2s
#      0     0 3797885.54    0  515          - 3797885.54      -     -    2s
#      0     0 3797885.54    0  347          - 3797885.54      -     -    2s
#      0     0 3797885.54    0  345          - 3797885.54      -     -    2s
#      0     0 3797885.54    0  308          - 3797885.54      -     -    3s
#      0     0 3797885.54    0  318          - 3797885.54      -     -    3s
#      0     0 3797906.64    0  318          - 3797906.64      -     -    3s
#      0     0 3797906.64    0  322          - 3797906.64      -     -    3s
#      0     0 3797906.64    0  358          - 3797906.64      -     -    4s
#      0     0 3797906.64    0  378          - 3797906.64      -     -    4s
#      0     0 3797906.64    0  390          - 3797906.64      -     -    4s
#      0     0 3797906.64    0  380          - 3797906.64      -     -    4s
#      0     0 3797906.64    0  235          - 3797906.64      -     -    4s
# H    0     0                    3798430.9918 3797906.64  0.01%     -    5s
#
# Cutting planes:
#   Gomory: 8
#   Lift-and-project: 1
#   Implied bound: 11
#   Clique: 315
#   MIR: 52
#   Zero half: 49
#   RLT: 60
#
# Explored 1 nodes (20549 simplex iterations) in 5.94 seconds (2.66 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 3.79843e+06
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.798430991842e+06, best bound 3.797906800468e+06, gap 0.0138%
# size = 3
# cluster = [10, 12]
# population =  [8728, 19581]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 38634913.73 	 0.00
# 2 	 38632229.86 	 0.00
# 3 	 38632229.86 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [14, 15, 60]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 35 rows, 24 columns and 123 nonzeros
# Model fingerprint: 0x853536a7
# Variable types: 6 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [5e+05, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 17 rows and 23 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 14 rows, 24 columns and 72 nonzeros
# Model fingerprint: 0x197aab01
# Variable types: 6 continuous, 18 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [5e+05, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 3 rows and 19 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 46, time in user-callback 0.01 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.02
# 1 	 59853424.23 	 0.01
# 2 	 32026195.08 	 0.01
# 3 	 31915089.11 	 0.01
# 4 	 31915089.11 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [8668, 115, 14710]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 15807 rows, 11853 columns and 62985 nonzeros
# Model fingerprint: 0x4e911660
# Variable types: 3110 continuous, 8743 integer (8743 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [2e+00, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 12754 rows and 9849 columns
# Presolve time: 0.73s
# Presolved: 3053 rows, 2004 columns, 12851 nonzeros
# Variable types: 0 continuous, 2004 integer (2004 binary)
#
# Root relaxation: objective 3.191580e+07, 1153 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.1916e+07    0    7          - 3.1916e+07      -     -    0s
# H    0     0                    3.193219e+07 3.1916e+07  0.05%     -    0s
#
# Explored 1 nodes (1433 simplex iterations) in 0.87 seconds (0.35 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 3.19322e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.193218679400e+07, best bound 3.191580128499e+07, gap 0.0513%
# size = 4
# cluster = [2, 3, 8, 11, 20]
# population =  [8605, 6838, 2467, 12498, 7181]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 59721514.07 	 0.00
# 2 	 59161145.85 	 0.00
# 3 	 59161145.85 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [92, 70, 77, 79]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 64 rows, 48 columns and 264 nonzeros
# Model fingerprint: 0x9dc8c229
# Variable types: 26 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [2e+05, 4e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 42 rows and 43 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 20 rows, 48 columns and 144 nonzeros
# Model fingerprint: 0xd2db8e47
# Variable types: 26 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [2e+05, 4e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 6 rows and 42 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 46, time in user-callback 0.00 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.02
# 1 	 67368629.90 	 0.02
# 2 	 66806162.93 	 0.01
# 3 	 66805972.29 	 0.01
# 4 	 66805972.29 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [23759, 42897, 2521, 11838]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 39144 rows, 31312 columns and 167284 nonzeros
# Model fingerprint: 0xb0670d6b
# Variable types: 18816 continuous, 12496 integer (12496 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [2e+00, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 31560 rows and 25945 columns
# Presolve time: 0.54s
# Presolved: 7584 rows, 5367 columns, 28834 nonzeros
# Variable types: 0 continuous, 5367 integer (5364 binary)
#
# Root relaxation: objective 6.682933e+07, 2941 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.6829e+07    0   39          - 6.6829e+07      -     -    0s
# H    0     0                    6.710837e+07 6.6829e+07  0.42%     -    0s
#
# Explored 1 nodes (4206 simplex iterations) in 0.76 seconds (0.34 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 6.71084e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.710837089098e+07, best bound 6.682932764912e+07, gap 0.4158%
# size = 7
# cluster = [14, 19]
# population =  [42272, 20450]
# L,U = 8839 9769
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 21140518.20 	 0.00
# 2 	 16017712.67 	 0.00
# 3 	 16008690.72 	 0.00
# 4 	 16008690.72 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [49, 80, 50, 48, 52, 21, 25]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 159 rows, 133 columns and 812 nonzeros
# Model fingerprint: 0xaa095fae
# Variable types: 50 continuous, 83 integer (83 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [6e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 119 rows and 95 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 33 rows, 133 columns and 399 nonzeros
# Model fingerprint: 0x246b7d4b
# Variable types: 50 continuous, 83 integer (83 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [6e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 0 rows and 50 columns
# Presolve time: 0.00s
# Presolved: 33 rows, 83 columns, 249 nonzeros
# Variable types: 0 continuous, 83 integer (83 binary)
#
# Root relaxation: infeasible, 22 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (22 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 183, time in user-callback 0.00 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.04
# 1 	 28472362.86 	 0.03
# 2 	 21285253.81 	 0.01
# 3 	 21261024.89 	 0.01
# 4 	 21260541.44 	 0.01
# 5 	 21260524.76 	 0.01
# 6 	 21260524.76 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [34148, 28246, 6020, 49696, 49318, 6194, 50006]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 43543 rows, 38094 columns and 199080 nonzeros
# Model fingerprint: 0x14334d50
# Variable types: 13838 continuous, 24256 integer (24256 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e-01, 1e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 19710 rows and 18658 columns
# Presolve time: 1.47s
# Presolved: 23833 rows, 19436 columns, 97866 nonzeros
# Variable types: 0 continuous, 19436 integer (19436 binary)
#
# Root relaxation: objective 2.126191e+07, 13315 iterations, 0.63 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.1262e+07    0 1285          - 2.1262e+07      -     -    3s
#      0     0 2.1263e+07    0 1591          - 2.1263e+07      -     -    4s
#      0     0 2.1263e+07    0 1592          - 2.1263e+07      -     -    4s
#      0     0 2.1263e+07    0 1595          - 2.1263e+07      -     -    4s
#      0     0 2.1263e+07    0 1898          - 2.1263e+07      -     -    5s
#      0     0 2.1263e+07    0 1812          - 2.1263e+07      -     -    5s
#      0     0 2.1263e+07    0 1873          - 2.1263e+07      -     -    5s
#      0     0 2.1263e+07    0 2730          - 2.1263e+07      -     -    9s
#      0     0 2.1263e+07    0 2534          - 2.1263e+07      -     -   10s
#      0     0 2.1263e+07    0 2592          - 2.1263e+07      -     -   10s
#      0     0 2.1263e+07    0 2564          - 2.1263e+07      -     -   10s
#      0     0 2.1263e+07    0 2382          - 2.1263e+07      -     -   12s
#      0     0 2.1263e+07    0 1861          - 2.1263e+07      -     -   12s
#      0     0 2.1263e+07    0 1864          - 2.1263e+07      -     -   12s
#      0     0 2.1263e+07    0 2134          - 2.1263e+07      -     -   13s
#      0     0 2.1263e+07    0 2120          - 2.1263e+07      -     -   14s
#      0     0 2.1263e+07    0 2171          - 2.1263e+07      -     -   15s
#      0     0 2.1263e+07    0 2143          - 2.1263e+07      -     -   15s
#      0     0 2.1263e+07    0 2201          - 2.1263e+07      -     -   16s
#      0     0 2.1263e+07    0 1550          - 2.1263e+07      -     -   16s
#      0     2 2.1263e+07    0 1456          - 2.1263e+07      -     -   19s
#      3     8 2.1264e+07    2 1285          - 2.1264e+07      -  1766   20s
#    560   608 2.1280e+07   55 1148          - 2.1265e+07      -  89.8   25s
#   1803  1891 2.1306e+07  125 1254          - 2.1265e+07      -  78.9   30s
#   3131  3229 2.1308e+07  249  679          - 2.1265e+07      -  86.9   35s
#   4634  4751 2.1284e+07   90 1863          - 2.1266e+07      -  84.5   40s
#   5580  5413 2.1280e+07   28 1278          - 2.1266e+07      -  97.5   47s
#   5582  5415 2.1285e+07   70 2254          - 2.1266e+07      -  97.5   50s
#   5584  5416 2.1280e+07   50 1823          - 2.1266e+07      -  97.4   56s
#   5586  5417 2.1314e+07  285 1780          - 2.1266e+07      -  97.4   62s
#   5588  5419 2.1291e+07   95 1719          - 2.1266e+07      -  97.4   66s
#   5633  5456 2.1275e+07   21 1693          - 2.1268e+07      -  14.4   70s
#   5859  5746 2.1282e+07   37 1728          - 2.1268e+07      -  20.2   75s
#   6168  6293 2.1282e+07   39 1687          - 2.1268e+07      -  26.7   81s
#   6670  6553 2.1283e+07   72 1668          - 2.1268e+07      -  33.7   85s
#   7450  6970 2.1386e+07  139 1695          - 2.1268e+07      -  45.8   90s
#   7795  7365 2.1290e+07  115 1415          - 2.1268e+07      -  49.9   96s
#   8337  7525 2.1285e+07  130 1148          - 2.1268e+07      -  56.1  100s
#   8737  7863 2.1285e+07  139 1052          - 2.1268e+07      -  66.7  106s
#   9282  8312 2.1288e+07  167 1187          - 2.1268e+07      -  76.1  112s
#   9996  9094 2.1292e+07  188 1348          - 2.1268e+07      -  83.0  123s
#  11116  9299 infeasible  240               - 2.1268e+07      -  81.0  134s
#  11800 10589 2.1269e+07   55 1547          - 2.1268e+07      -  86.6  142s
#  13461 10766 2.1271e+07  154 1241          - 2.1268e+07      -  84.8  148s
#  14261 11566 2.1278e+07  190  829          - 2.1268e+07      -  86.9  155s
#  15416 12045 2.1319e+07  298  654          - 2.1268e+07      -  89.1  161s
#  16431 12254 2.1269e+07   60 1610          - 2.1268e+07      -  92.2  168s
#  17041 14177 2.1277e+07   89 1431          - 2.1268e+07      -  96.0  182s
#  19381 14085 infeasible  236               - 2.1268e+07      -  93.2  188s
#  20187 15018 2.1344e+07  322  858          - 2.1268e+07      -  94.0  194s
#  21540 15134 2.1271e+07   82 1495          - 2.1268e+07      -  94.1  201s
#  22190 16083 2.1944e+07   37 1434          - 2.1268e+07      -  96.8  209s
#  23300 16786 2.1960e+07   78 1273          - 2.1268e+07      -  98.1  217s
#  24101 17720 2.1971e+07  132  655          - 2.1268e+07      -   101  225s
#  25156 18357 2.1268e+07   31 1425          - 2.1268e+07      -   104  233s
#  25851 19093 2.1270e+07   53 1298          - 2.1268e+07      -   107  247s
#  26676 19711 2.1272e+07   62 1526          - 2.1268e+07      -   107  256s
#  27377 21122 2.1375e+07   51 1171          - 2.1268e+07      -   111  265s
#  28931 22106 2.1273e+07   76 1836          - 2.1268e+07      -   112  276s
#  29958 23949 2.1277e+07  140 1169          - 2.1268e+07      -   114  287s
#  32061 25069 2.1313e+07  199  419          - 2.1268e+07      -   115  297s
#  33365 26064 2.1274e+07   76 1578          - 2.1268e+07      -   118  423s
#  34461 28215 2.1277e+07  124 1913          - 2.1268e+07      -   120  440s
#  36856 29780 2.1374e+07   45 1490          - 2.1268e+07      -   122  453s
# *37155 19118             262    2.128729e+07 2.1268e+07  0.09%   122  453s
#
# Cutting planes:
#   Gomory: 28
#   Lift-and-project: 7
#   Cover: 3
#   Implied bound: 6
#   Clique: 559
#   MIR: 58
#   StrongCG: 7
#   Flow cover: 235
#   GUB cover: 1
#   Zero half: 228
#   RLT: 151
#
# Explored 38914 nodes (5306436 simplex iterations) in 453.76 seconds (267.51 work units)
# ...
# Model fingerprint: 0x235dd166
# Variable types: 16 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [3e+03, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 107 rows and 79 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 41 columns, 188 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
# Found heuristic solution: objective 5.770059e+07
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 5.77006e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.770058709783e+07, best bound 5.378528141637e+07, gap 6.7856%
# size = 6
# cluster = [1, 11]
# population =  [100512, 12498]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 40422802.69 	 0.00
# 2 	 38377542.07 	 0.00
# 3 	 38349519.44 	 0.00
# 4 	 38349519.44 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [136, 83, 69, 154, 38, 95]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 223 rows, 186 columns and 1218 nonzeros
# Model fingerprint: 0x7d2d5b24
# Variable types: 20 continuous, 166 integer (166 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [3e+01, 7e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 110 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 113 rows, 103 columns, 583 nonzeros
# Variable types: 0 continuous, 103 integer (103 binary)
#
# Root relaxation: objective 4.354754e+07, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.3548e+07    0   12          - 4.3548e+07      -     -    0s
# H    0     0                    4.555327e+07 4.3548e+07  4.40%     -    0s
#
# Explored 1 nodes (38 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 4.55533e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.555326975398e+07, best bound 4.354753907938e+07, gap 4.4030%
# size = 1
# cluster = [2, 3, 8]
# population =  [2467, 8605, 6838]
# L,U = 17678 19538
# size = 2
# cluster = [4]
# population =  [37066]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 3454256.92 	 0.00
# 2 	 3404252.92 	 0.00
# 3 	 3274119.19 	 0.00
# 4 	 3208512.06 	 0.00
# 5 	 3206790.30 	 0.00
# 6 	 3206790.30 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [108, 107]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 35 rows, 22 columns and 134 nonzeros
# Model fingerprint: 0xf28763a1
# Variable types: 0 continuous, 22 integer (22 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [2e+03, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Found heuristic solution: objective 4512517.0757
# Presolve removed 24 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 9 columns, 47 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 3252165.1286
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 3.25217e+06 4.51252e+06
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.252165128648e+06, best bound 2.958783789179e+06, gap 9.0211%
# size = 3
# cluster = [19, 21]
# population =  [42272, 14537]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 96696257.36 	 0.00
# 2 	 91329826.89 	 0.00
# 3 	 91329826.89 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [47, 45, 151]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 75 rows, 54 columns and 330 nonzeros
# Model fingerprint: 0x6a0849a7
# Variable types: 10 continuous, 44 integer (44 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [6e+03, 2e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 56 rows and 37 columns
# Presolve time: 0.00s
# Presolved: 19 rows, 17 columns, 82 nonzeros
# Variable types: 0 continuous, 17 integer (17 binary)
# Found heuristic solution: objective 1.177511e+08
#
# Root relaxation: objective 1.069249e+08, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.0692e+08    0    6 1.1775e+08 1.0692e+08  9.19%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 1.17751e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.177511113311e+08, best bound 1.069249416566e+08, gap 9.1941%
# size = 4
# cluster = [9, 10, 12, 14]
# population =  [23331, 8728, 19581, 20450]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 153620138.21 	 0.00
# 2 	 147642179.54 	 0.00
# 3 	 146647336.34 	 0.00
# 4 	 146647336.34 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [91, 128, 21, 15]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 109 rows, 84 columns and 472 nonzeros
# Model fingerprint: 0x23f9d3fb
# Variable types: 45 continuous, 39 integer (39 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [1e+05, 4e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 83 rows and 70 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 29 rows, 84 columns and 252 nonzeros
# Model fingerprint: 0xead520ed
# Variable types: 45 continuous, 39 integer (39 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [1e+05, 4e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 24 rows and 75 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 29 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 1.778753e+08, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7788e+08    0    -          - 1.7788e+08      -     -    0s
#
# Cutting planes:
#   Lazy constraints: 5
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 341, time in user-callback 0.02 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.04
# 1 	 131366032.05 	 0.01
# 2 	 129376727.84 	 0.01
# 3 	 129375618.02 	 0.01
# 4 	 129375617.99 	 0.01
# 5 	 129375617.99 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [27020, 24852, 37524, 12915]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 33464 rows, 26768 columns and 142460 nonzeros
# Model fingerprint: 0x597df8a5
# Variable types: 14939 continuous, 11829 integer (11829 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [2e+00, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 29190 rows and 24505 columns
# Presolve time: 1.19s
# Presolved: 4274 rows, 2263 columns, 15939 nonzeros
# Variable types: 0 continuous, 2263 integer (2257 binary)
#
# Root relaxation: objective 1.293820e+08, 680 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2938e+08    0   44          - 1.2938e+08      -     -    1s
# H    0     0                    1.310248e+08 1.2938e+08  1.25%     -    1s
#
# Explored 1 nodes (1217 simplex iterations) in 1.36 seconds (0.58 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 1.31025e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.310248151023e+08, best bound 1.293819935404e+08, gap 1.2538%
# size = 4
# cluster = [5, 13, 16]
# population =  [4621, 39234, 29624]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 116540406.85 	 0.00
# 2 	 108695979.68 	 0.00
# 3 	 108695979.68 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [42, 61, 1, 2]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 109 rows, 84 columns and 504 nonzeros
# Model fingerprint: 0x827d047d
# Variable types: 32 continuous, 52 integer (52 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [8e+04, 3e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 109 rows and 84 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 1: 1.6147e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.614700273325e+08, best bound 1.614700273325e+08, gap 0.0000%
# size = 3
# cluster = [6, 7, 15, 17]
# population =  [7685, 11521, 8447, 30921]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 91455892.13 	 0.00
# 2 	 90137335.29 	 0.00
# 3 	 90137335.29 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [66, 65, 27]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 67 rows, 48 columns and 285 nonzeros
# Model fingerprint: 0x69d85e06
# Variable types: 22 continuous, 26 integer (26 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [1e+05, 7e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 62 rows and 42 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Trying a,b-separator model.
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 22 rows, 48 columns and 144 nonzeros
# Model fingerprint: 0x1acc1912
# Variable types: 22 continuous, 26 integer (26 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [1e+05, 7e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 19 rows and 40 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 88, time in user-callback 0.01 sec
# Trying block-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.03
# 1 	 120266621.12 	 0.01
# 2 	 118233421.91 	 0.01
# 3 	 118202616.00 	 0.01
# 4 	 118202154.65 	 0.01
# 5 	 118202115.32 	 0.01
# 6 	 118202115.31 	 0.01
# 7 	 118202115.31 	 0.01
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [9411, 18520, 42418]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 28271 rows, 21201 columns and 114573 nonzeros
# Model fingerprint: 0xe9580c85
# Variable types: 10032 continuous, 11169 integer (11169 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [2e-01, 3e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 23472 rows and 18632 columns
# Presolve time: 0.57s
# Presolved: 4799 rows, 2569 columns, 16387 nonzeros
# Variable types: 0 continuous, 2569 integer (2565 binary)
#
# Root relaxation: objective 1.182151e+08, 667 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1822e+08    0    3          - 1.1822e+08      -     -    0s
# H    0     0                    1.182178e+08 1.1822e+08  0.00%     -    0s
#
# Explored 1 nodes (1028 simplex iterations) in 0.74 seconds (0.30 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 1.18218e+08
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.182177897938e+08, best bound 1.182150626696e+08, gap 0.0023%
# size = 3
# cluster = [20, 22]
# population =  [7181, 47026]
# L,U = 17678 19538
# Trying tract-level instance.
# Iteration 	 Objective 	 iter_time
# 0 	 0.00 	 0.00
# 1 	 43875839.85 	 0.00
# 2 	 37386685.77 	 0.00
# 3 	 37386685.77 	 0.00
# Set parameter OutputFlag to value 1
# Trying DAG model, with roots = [134, 10, 133]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 51 rows, 36 columns and 213 nonzeros
# Model fingerprint: 0x2bad2935
# Variable types: 4 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [5e+04, 4e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+04]
# Presolve removed 51 rows and 36 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 1: 6.13699e+07
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.136993944649e+07, best bound 6.136993944649e+07, gap 0.0000%

# %%
print("results =",results)
# Out:
# results = {('WY', 'SH'): {'clusters': [[1], [0], [5, 9, 13, 16], [6, 7, 15, 17], [4], [10, 12], [2, 3, 8, 11, 20], [14, 19], [18, 21], [22]], 'num_clusters': 10, 'sizes': [11, 9, 10, 6, 4, 3, 4, 7, 3, 5], 'districts': [['560210019021080', '560210011002062', '560210019021010', '560210011002065', '560210019022135', '560210019021171', '560210019021064', '560210019021059', '560210012001007', '560210019023156', '560210019022074', '560210012002020', '560210011002029', '560210019022041', '560210019022045', '560210019022077', '560210019023212', '560210019021154', '560210019022111', '560210019023197', '560210019021149', '560210011002024', '560210019022185', '560210012001035', '560210019022088', '560210019021191', '560210019021040', '560210011003010', '560210019023107', '560210019022044', '560210019023126', '560210019022063', '560210012001048', '560210019021151', '560210019021024', '560210019021132', '560210012001029', '560210019023173', '560210019023074', '560210012001034', '560210019023059', '560210019023176', '560210011002030', '560210011001003', '560210019022141', '560210019022145', '560210011002025', '560210019022128', '560210019022166', '560210019023163', '560210019022159', '560210019022051', '560210019021014', '560210019021230', '560210019022162', '560210019023024', '560210011001012', '560210019022061', '560210019021097', '560210019023056', '560210019022081', '560210019022086', '560210012002029', '560210011002023', '560210019023196', '560210019021067', '560210019022165', '560210019022005', '560210019022027', '560210019023095', '560210019021048', '560210019023037', '560210011001006', '560210019021174', '560210019021063', '560210019022000', '560210019022085', '560210019021173', '560210019023157', '560210019023061', '560210012002032', '560210019023046', '560210019022138', '560210019023101', '560210019023110', '560210012001012', '560210019022133', '560210019023086', '560210011001010', '560210019021028', '560210019023200', '560210019021110', '560210011001011', '560210011002060', '560210019021056', '560210011002028', '560210011002022', '560210011002014', '560210019021159', '560210007022062', '560210019023043', '560210019023004', '560210007022067', '560210012001030', '560210019022054', '560210019021138', '560210019021046', '560210011002011', '560210012001025', '560210019022115', '560210019023071', '560210019023087', '560210019021130', '560210019021084', '560210019021020', '560210019021082', '560210019023178', '560210019023068', '560210019021081', '560210019023064', '560210012002021', '560210019023077', '560210019021032', '560210019022076', '560210019023122', '560210019021068', '560210019021016', '560210019022152', '560210019021129', '560210019022064', '560210019022122', '560210019022065', '560210019023159', '560210012002009', '560210019022067', '560210019023180', '560210019023183', '560210019022017', '560210012001049', '560210019021162', '560210019023111', '560210019021237', '560210019023167', '560210019022101', '560210019023082', '560210012002031', '560210011002041', '560210019023112', '560210012001032', '560210019021155', '560210019023179', '560210019023012', '560210019022179', '560210019022177', '560210011001005', '560210019022069', '560210019021044', '560210019023090', '560210019021096', '560210019021031', '560210019022090', '560210019022136', '560210019021054', '560210019023048', '560210019023181', '560210019023191', '560210019023158', '560210012001037', '560210019022040', '560210011003008', '560210011002008', '560210019021216', '560210019022098', '560210019021228', '560210019022153', '560210019022100', '560210019023203', '560210019022123', '560210011002015', '560210019021076', '560210019021050', '560210019022158', '560210011001009', '560210019023081', '560210012001050', '560210019023097', '560210019022038', '560210019021229', '560210011001004', '560210019021065', '560210019021234', '560210019022095', '560210019022018', '560210019023075', '560210019021131', '560210019023096', '560210019021109', '560210019021094', '560210019022125', ...

# %%
print('state  district_type  splits_LB  splits_UB  gap')
for (state, district_type) in results.keys():
    splits_LB = results[state,district_type]['k'] - clusterings[state,district_type]['cluster_UB']
    splits_UB = results[state,district_type]['splits_UB'] 
    if splits_UB is None:
        print(state,district_type, splits_LB, splits_UB, 'None')
    else:
        print(state,district_type, splits_LB, splits_UB, splits_UB-splits_LB)
# Out:
# state  district_type  splits_LB  splits_UB  gap
# WY SH 52 52 0
# WY SS 22 22 0

# %%
for district_type in ['CD', 'SS', 'SH']:
    print("results for",district_type,":")
    print("state |C| k L U obvious_LB max_clusters split_LB min_splits enacted_splits")
    for state in states:
        if (state, district_type) in results.keys():
            s = state
            t = district_type
            print(state,end=' & ')
            print(results[s,t]['counties'],end=' & ')
            print(results[s,t]['k'],end=' & ')
            print(results[s,t]['L'],end=' & ')
            print(results[s,t]['U'],end=' & ')
            print(results[s,t]['obvious_LB'],end=' & ')
            print(results[s,t]['num_clusters'],end=' & ')
            print(results[s,t]['splits_LB'],end=' & ')
            print(results[s,t]['splits_UB'],end=' & ')
            print(enacted_splits[s,t],'\\\\')  
            
    print("\n\n")
# Out:
# results for CD :
# state |C| k L U obvious_LB max_clusters split_LB min_splits enacted_splits
#
#
#
# results for SS :
# state |C| k L U obvious_LB max_clusters split_LB min_splits enacted_splits
# WY & 23 & 31 & 17,678 & 19,538 & 21 & 9 & 22 & 22 & 25 \\
#
#
#
# results for SH :
# state |C| k L U obvious_LB max_clusters split_LB min_splits enacted_splits
# WY & 23 & 62 & 8,839 & 9,769 & 49 & 10 & 52 & 52 & 56 \\
